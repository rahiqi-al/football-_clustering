# %%
from functions import reterive_clean_data
from config.config import config
import pandas as pd
import numpy as np

# %%
# it s working 
df_match,df_team,df_player = reterive_clean_data('general')
# Out:
# /home/ali/Desktop/EuroFootballClustering/functions.py:46: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_player['potential'].fillna(df_player['potential'].mean(), inplace = True)
# /home/ali/Desktop/EuroFootballClustering/functions.py:47: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_player['overall_rating'].fillna(df_player['overall_rating'].mean(), inplace = True)

# %% [markdown]
# #                    ------------------------player------------------------

# %%
df_player
# Out:
#         id_player         player_name             birthday  height  weight  \
# 0               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 1               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 2               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 3               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 4               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# ...           ...                 ...                  ...     ...     ...
# 183973      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
# 183974      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
# 183975      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
# 183976      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
# 183977      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
#
#         id_attribute  player_id       date  overall_rating  potential  ...  \
# 0                  1     505942 2016-02-18            67.0       71.0  ...
# 1                  2     505942 2015-11-19            67.0       71.0  ...
# 2                  3     505942 2015-09-21            62.0       66.0  ...
# 3                  4     505942 2015-03-20            61.0       65.0  ...
# 4                  5     505942 2007-02-22            61.0       65.0  ...
# ...              ...        ...        ...             ...        ...  ...
# 183973        183974      39902 2009-08-30            83.0       85.0  ...
# 183974        183975      39902 2009-02-22            78.0       80.0  ...
# 183975        183976      39902 2008-08-30            77.0       80.0  ...
# 183976        183977      39902 2007-08-30            78.0       81.0  ...
# 183977        183978      39902 2007-02-22            80.0       81.0  ...
#
#        penalties marking standing_tackle  sliding_tackle  gk_diving  \
# 0           48.0    65.0            69.0            69.0        6.0
# 1           48.0    65.0            69.0            69.0        6.0
# 2           48.0    65.0            66.0            69.0        6.0
# 3           47.0    62.0            63.0            66.0        5.0
# 4           47.0    62.0            63.0            66.0        5.0
# ...          ...     ...             ...             ...        ...
# 183973      83.0    22.0            31.0            30.0        9.0
# 183974      70.0    32.0            31.0            30.0        9.0
# 183975      70.0    32.0            31.0            30.0        9.0
# 183976      53.0    28.0            32.0            30.0        9.0
# 183977      53.0    38.0            32.0            30.0        9.0
#
#         gk_handling  gk_kicking  gk_positioning  gk_reflexes     season
# 0              11.0        10.0             8.0          8.0  2015/2016
# 1              11.0        10.0             8.0          8.0  2015/2016
# 2              11.0        10.0             8.0          8.0  2015/2016
# 3              10.0         9.0             7.0          7.0  2014/2015
# 4              10.0         9.0             7.0          7.0  2006/2007
# ...             ...         ...             ...          ...        ...
# 183973         20.0        84.0            20.0         20.0  2009/2010
# 183974         20.0        73.0            20.0         20.0  2008/2009
# 183975         20.0        73.0            20.0         20.0  2008/2009
# 183976         20.0        73.0            20.0         20.0  2007/2008
# 183977          9.0        78.0             7.0         15.0  2006/2007
#
# [183978 rows x 47 columns]

# %%
df_player['metrique_performance']=df_player['overall_rating']*0.7+df_player['potential']*0.3

# %%
df_player.head()
# Out:
#    id_player         player_name             birthday  height  weight  \
# 0          1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 1          1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 2          1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 3          1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 4          1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
#
#    id_attribute  player_id       date  overall_rating  potential  ... marking  \
# 0             1     505942 2016-02-18            67.0       71.0  ...    65.0
# 1             2     505942 2015-11-19            67.0       71.0  ...    65.0
# 2             3     505942 2015-09-21            62.0       66.0  ...    65.0
# 3             4     505942 2015-03-20            61.0       65.0  ...    62.0
# 4             5     505942 2007-02-22            61.0       65.0  ...    62.0
#
#   standing_tackle sliding_tackle  gk_diving  gk_handling  gk_kicking  \
# 0            69.0           69.0        6.0         11.0        10.0
# 1            69.0           69.0        6.0         11.0        10.0
# 2            66.0           69.0        6.0         11.0        10.0
# 3            63.0           66.0        5.0         10.0         9.0
# 4            63.0           66.0        5.0         10.0         9.0
#
#    gk_positioning  gk_reflexes     season  metrique_performance
# 0             8.0          8.0  2015/2016                  68.2
# 1             8.0          8.0  2015/2016                  68.2
# 2             8.0          8.0  2015/2016                  63.2
# 3             7.0          7.0  2014/2015                  62.2
# 4             7.0          7.0  2006/2007                  62.2
#
# [5 rows x 48 columns]

# %%
df_player.metrique_performance.isnull().sum()
# Out:
# np.int64(0)

# %%
def plus_performants(group):
    sorted_group = group.sort_values(by='metrique_performance', ascending=False)
    # display(sorted_group)
    return sorted_group.head(1)


df_player_plus_performants = df_player.groupby('season').apply(plus_performants).reset_index(drop=True)
# Out:
# /tmp/ipykernel_38949/2650212605.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_player_plus_performants = df_player.groupby('season').apply(plus_performants).reset_index(drop=True)

# %%
df_player_plus_performants.head(15)
# Out:
#    id_player        player_name             birthday  height  weight  \
# 0       3826   Gianluigi Buffon  1978-01-28 00:00:00  193.04     201
# 1       1995  Cristiano Ronaldo  1985-02-05 00:00:00  185.42     176
# 2       1995  Cristiano Ronaldo  1985-02-05 00:00:00  185.42     176
# 3       6176       Lionel Messi  1987-06-24 00:00:00  170.18     159
# 4       6176       Lionel Messi  1987-06-24 00:00:00  170.18     159
# 5       6176       Lionel Messi  1987-06-24 00:00:00  170.18     159
# 6       6176       Lionel Messi  1987-06-24 00:00:00  170.18     159
# 7       6176       Lionel Messi  1987-06-24 00:00:00  170.18     159
# 8       6176       Lionel Messi  1987-06-24 00:00:00  170.18     159
# 9       6176       Lionel Messi  1987-06-24 00:00:00  170.18     159
#
#    id_attribute  player_id       date  overall_rating  potential  ... marking  \
# 0         63876      30717 2007-02-22            93.0       93.0  ...     8.0
# 1         33354      30893 2007-08-30            91.0       94.0  ...    27.0
# 2         33353      30893 2008-08-30            91.0       94.0  ...    27.0
# 3        102504      30981 2009-08-30            90.0       95.0  ...    20.0
# 4        102502      30981 2010-08-30            90.0       95.0  ...    13.0
# 5        102499      30981 2012-02-22            94.0       96.0  ...    13.0
# 6        102495      30981 2013-03-22            94.0       97.0  ...    13.0
# 7        102493      30981 2013-11-15            94.0       97.0  ...    25.0
# 8        102487      30981 2015-03-13            93.0       95.0  ...    25.0
# 9        102485      30981 2015-09-21            94.0       95.0  ...    13.0
#
#   standing_tackle sliding_tackle  gk_diving  gk_handling  gk_kicking  \
# 0             8.0            9.0       91.0         93.0        76.0
# 1            27.0           23.0        9.0         21.0        73.0
# 2            35.0           23.0        9.0         21.0        72.0
# 3            21.0           20.0        8.0         20.0        75.0
# 4            21.0           20.0        6.0         11.0        15.0
# 5            21.0           20.0        6.0         11.0        15.0
# 6            21.0           20.0        6.0         11.0        15.0
# 7            21.0           20.0        6.0         11.0        15.0
# 8            21.0           20.0        6.0         11.0        15.0
# 9            23.0           21.0        6.0         11.0        15.0
#
#    gk_positioning  gk_reflexes     season  metrique_performance
# 0            96.0         93.0  2006/2007                  93.0
# 1            21.0         21.0  2007/2008                  91.9
# 2            21.0         21.0  2008/2009                  91.9
# 3            20.0         20.0  2009/2010                  91.5
# 4            14.0          8.0  2010/2011                  91.5
# 5            14.0          8.0  2011/2012                  94.6
# 6            14.0          8.0  2012/2013                  94.9
# 7            14.0          8.0  2013/2014                  94.9
# 8            14.0          8.0  2014/2015                  93.6
# 9            14.0          8.0  2015/2016                  94.3
#
# [10 rows x 48 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.bar(df_player_plus_performants.head(6)['season'].astype(str), df_player_plus_performants.head(6)['metrique_performance'], color='skyblue')

for _, row in df_player_plus_performants.head(6).iterrows():
    plt.text(row['season'], row['metrique_performance'] + 1, row['player_name'], ha='center', va='bottom')

plt.xlabel('Season')
plt.ylabel('Métrique Performance')
plt.title('les joueurs les plus performants de chaque saison')
plt.xticks(rotation=45) 

plt.tight_layout()
plt.show()

# %%
#les joueurs les plus constants en performance au fil des saisons

# %%
# we need to calculate the std to see if the performance stay steady or change a lot (the smaller the better)

df_player_constant_profermonce=df_player.groupby('player_name')['metrique_performance'].std().reset_index()
df_player_constant_profermonce.columns=['player_name','std_of_performance']
display(df_player_constant_profermonce.sort_values(by='std_of_performance'))
df_player_constant_profermonce=df_player_constant_profermonce.sort_values(by='std_of_performance')
# the result make sense cause its the most consistants performance doesnt mean his the best
display(df_player_constant_profermonce[df_player_constant_profermonce['player_name']=='Lionel Messi'])
# above to make sure
#display(df_player_constant_profermonce)
# Out:
#                 player_name  std_of_performance
# 8321       Pedro Chirivella            0.000000
# 461       Alexandre Azevedo            0.000000
# 10494  Vytautas Cerniauskas            0.000000
# 10487     Volodymyr Tanchyk            0.000000
# 10478       Vladimir Volkov            0.000000
# ...                     ...                 ...
# 5843            Lamine Kone           10.772985
# 6599       Marco Sportiello           10.869207
# 9164           Sabin Merino           10.889764
# 7064          Mattia Notari           11.518406
# 4367             Ivan Juric           15.688435
#
# [10848 rows x 2 columns]
#        player_name  std_of_performance
# 6053  Lionel Messi            2.021184

# %%
player_canstant_performance=list(df_player_constant_profermonce.player_name.values)
#player_canstant_performance

# %%
df_player['season'] = df_player['season'].apply(lambda x : int(x.split('/')[0]))
df_player.head()
#display(df_player[df_player['player_name']=='Lionel Messi'])
# Out:
#    id_player         player_name             birthday  height  weight  \
# 0          1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 1          1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 2          1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 3          1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 4          1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
#
#    id_attribute  player_id       date  overall_rating  potential  ... marking  \
# 0             1     505942 2016-02-18            67.0       71.0  ...    65.0
# 1             2     505942 2015-11-19            67.0       71.0  ...    65.0
# 2             3     505942 2015-09-21            62.0       66.0  ...    65.0
# 3             4     505942 2015-03-20            61.0       65.0  ...    62.0
# 4             5     505942 2007-02-22            61.0       65.0  ...    62.0
#
#   standing_tackle sliding_tackle  gk_diving  gk_handling  gk_kicking  \
# 0            69.0           69.0        6.0         11.0        10.0
# 1            69.0           69.0        6.0         11.0        10.0
# 2            66.0           69.0        6.0         11.0        10.0
# 3            63.0           66.0        5.0         10.0         9.0
# 4            63.0           66.0        5.0         10.0         9.0
#
#    gk_positioning  gk_reflexes  season  metrique_performance
# 0             8.0          8.0    2015                  68.2
# 1             8.0          8.0    2015                  68.2
# 2             8.0          8.0    2015                  63.2
# 3             7.0          7.0    2014                  62.2
# 4             7.0          7.0    2006                  62.2
#
# [5 rows x 48 columns]

# %%
plt.figure(figsize=(10, 6))
for player in player_canstant_performance[4853:4857]:
    player_data = df_player[df_player["player_name"] == player]
    plt.plot(
        player_data["season"],
        player_data["metrique_performance"],
        marker="o",
        label=f"Player {player}",
    )

plt.title(" les joueurs les plus constants en performance au fil des saisons", fontsize=14)
plt.xlabel("season", fontsize=12)
plt.ylabel("performance score", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend(title="players", fontsize=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### ----------------------------- Analyse des Tendances -----------------------------

# %%
plt.figure(figsize=(10, 6))
for player_id in df_player["player_name"].unique()[:4]:
    player_data = df_player[df_player["player_name"] == player_id]
    plt.plot(
        player_data["season"],
        player_data["metrique_performance"],
        marker="o",
        label=f"Player {player_id}",
    )

plt.title("les performances globales des joueurs ou équipes évoluent au fil des saisons", fontsize=14)
plt.xlabel("season", fontsize=12)
plt.ylabel("performance score", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend(title="players", fontsize=10)
plt.tight_layout()
plt.show()

# %%
df_player
# Out:
#         id_player         player_name             birthday  height  weight  \
# 0               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 1               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 2               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 3               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 4               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# ...           ...                 ...                  ...     ...     ...
# 183973      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
# 183974      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
# 183975      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
# 183976      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
# 183977      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
#
#         id_attribute  player_id       date  overall_rating  potential  ...  \
# 0                  1     505942 2016-02-18            67.0       71.0  ...
# 1                  2     505942 2015-11-19            67.0       71.0  ...
# 2                  3     505942 2015-09-21            62.0       66.0  ...
# 3                  4     505942 2015-03-20            61.0       65.0  ...
# 4                  5     505942 2007-02-22            61.0       65.0  ...
# ...              ...        ...        ...             ...        ...  ...
# 183973        183974      39902 2009-08-30            83.0       85.0  ...
# 183974        183975      39902 2009-02-22            78.0       80.0  ...
# 183975        183976      39902 2008-08-30            77.0       80.0  ...
# 183976        183977      39902 2007-08-30            78.0       81.0  ...
# 183977        183978      39902 2007-02-22            80.0       81.0  ...
#
#        marking standing_tackle sliding_tackle  gk_diving  gk_handling  \
# 0         65.0            69.0           69.0        6.0         11.0
# 1         65.0            69.0           69.0        6.0         11.0
# 2         65.0            66.0           69.0        6.0         11.0
# 3         62.0            63.0           66.0        5.0         10.0
# 4         62.0            63.0           66.0        5.0         10.0
# ...        ...             ...            ...        ...          ...
# 183973    22.0            31.0           30.0        9.0         20.0
# 183974    32.0            31.0           30.0        9.0         20.0
# 183975    32.0            31.0           30.0        9.0         20.0
# 183976    28.0            32.0           30.0        9.0         20.0
# 183977    38.0            32.0           30.0        9.0          9.0
#
#         gk_kicking  gk_positioning  gk_reflexes  season  metrique_performance
# 0             10.0             8.0          8.0    2015                  68.2
# 1             10.0             8.0          8.0    2015                  68.2
# 2             10.0             8.0          8.0    2015                  63.2
# 3              9.0             7.0          7.0    2014                  62.2
# 4              9.0             7.0          7.0    2006                  62.2
# ...            ...             ...          ...     ...                   ...
# 183973        84.0            20.0         20.0    2009                  83.6
# 183974        73.0            20.0         20.0    2008                  78.6
# 183975        73.0            20.0         20.0    2008                  77.9
# 183976        73.0            20.0         20.0    2007                  78.9
# 183977        78.0             7.0         15.0    2006                  80.3
#
# [183978 rows x 48 columns]

# %%
#les périodes où  joueurs ont eu des performances exceptionnelles

# %%
def performance_exp(group):
    return group.sort_values(by='metrique_performance',ascending=False).iloc[0]
 

df_player_performonce_exceptionnelles = df_player.groupby('player_name').apply(performance_exp).reset_index(drop=True)
df_player_performonce_exceptionnelles
# Out:
# /tmp/ipykernel_38949/1708835859.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_player_performonce_exceptionnelles = df_player.groupby('player_name').apply(performance_exp).reset_index(drop=True)
#        id_player                  player_name             birthday  height  \
# 0              1           Aaron Appindangoye  1992-02-29 00:00:00  182.88
# 1              2              Aaron Cresswell  1989-12-15 00:00:00  170.18
# 2              3                  Aaron Doran  1991-05-13 00:00:00  170.18
# 3              4                Aaron Galindo  1982-05-08 00:00:00  182.88
# 4              5                 Aaron Hughes  1979-11-08 00:00:00  182.88
# ...          ...                          ...                  ...     ...
# 10843      11073                    Zsolt Low  1979-04-29 00:00:00  180.34
# 10844      11074          Zurab Khizanishvili  1981-10-06 00:00:00  185.42
# 10845      11075           Zvjezdan Misimovic  1982-06-05 00:00:00  180.34
# 10846       2483  de Oliveira Cleber Monteiro  1980-05-23 00:00:00  182.88
# 10847       2775      dos Santos Fabio Junior  1982-10-06 00:00:00  175.26
#
#        weight  id_attribute  player_id       date  overall_rating  potential  \
# 0         187             1     505942 2016-02-18            67.0       71.0
# 1         146            12     155782 2015-09-25            74.0       78.0
# 2         163            48     162549 2013-09-20            71.0       78.0
# 3         198            84      30572 2009-02-22            75.0       82.0
# 4         154           107      23780 2010-02-22            78.0       81.0
# ...       ...           ...        ...        ...             ...        ...
# 10843     154        183956      36491 2009-08-30            68.0       74.0
# 10844     172        183968      35506 2007-02-22            78.0       79.0
# 10845     176        183973      39902 2010-08-30            83.0       85.0
# 10846     170         41620      11833 2011-02-22            69.0       72.0
# 10847     174         46290      38804 2011-02-22            70.0       74.0
#
#        ... marking standing_tackle sliding_tackle  gk_diving  gk_handling  \
# 0      ...    65.0            69.0           69.0        6.0         11.0
# 1      ...    76.0            75.0           78.0       14.0          7.0
# 2      ...    22.0            21.0           21.0       15.0         10.0
# 3      ...    80.0            78.0           70.0       14.0         11.0
# 4      ...    82.0            83.0           77.0       12.0         20.0
# ...    ...     ...             ...            ...        ...          ...
# 10843  ...    71.0            71.0           59.0        4.0         21.0
# 10844  ...    79.0            84.0           65.0       14.0          9.0
# 10845  ...    22.0            31.0           30.0        9.0         13.0
# 10846  ...    67.0            69.0           72.0       15.0         15.0
# 10847  ...    34.0            26.0           18.0       13.0         12.0
#
#        gk_kicking  gk_positioning  gk_reflexes  season  metrique_performance
# 0            10.0             8.0          8.0    2015                  68.2
# 1             9.0             9.0         12.0    2015                  75.2
# 2            11.0             8.0         12.0    2013                  73.1
# 3            65.0            11.0         10.0    2008                  77.1
# 4            57.0            20.0         20.0    2009                  78.9
# ...           ...             ...          ...     ...                   ...
# 10843        61.0            21.0         21.0    2009                  69.8
# 10844        48.0             7.0         11.0    2006                  78.3
# 10845         8.0            15.0          5.0    2010                  83.6
# 10846        15.0            12.0         14.0    2010                  69.9
# 10847        12.0             7.0         11.0    2010                  71.2
#
# [10848 rows x 48 columns]

# %% [markdown]
# # -----------------------team/match-----------------

# %% [markdown]
# ##### 1) match

# %%
df_match
# Out:
#           id  country_id     season  stage                 date  match_api_id  \
# 0          1           1  2008/2009      1  2008-08-17 00:00:00        492473
# 1          2           1  2008/2009      1  2008-08-16 00:00:00        492474
# 2          3           1  2008/2009      1  2008-08-16 00:00:00        492475
# 3          4           1  2008/2009      1  2008-08-17 00:00:00        492476
# 4          5           1  2008/2009      1  2008-08-16 00:00:00        492477
# ...      ...         ...        ...    ...                  ...           ...
# 25974  25975       24558  2015/2016      9  2015-09-22 00:00:00       1992091
# 25975  25976       24558  2015/2016      9  2015-09-23 00:00:00       1992092
# 25976  25977       24558  2015/2016      9  2015-09-23 00:00:00       1992093
# 25977  25978       24558  2015/2016      9  2015-09-22 00:00:00       1992094
# 25978  25979       24558  2015/2016      9  2015-09-23 00:00:00       1992095
#
#        home_team_api_id  away_team_api_id  home_team_goal  away_team_goal  \
# 0                  9987              9993               1               1
# 1                 10000              9994               0               0
# 2                  9984              8635               0               3
# 3                  9991              9998               5               0
# 4                  7947              9985               1               3
# ...                 ...               ...             ...             ...
# 25974             10190             10191               1               0
# 25975              9824             10199               1               2
# 25976              9956             10179               2               0
# 25977              7896             10243               0               0
# 25978             10192              9931               4               3
#
#        ...  shotoff  foulcommit  card  cross  corner  possession  \
# 0      ...     None        None  None   None    None        None
# 1      ...     None        None  None   None    None        None
# 2      ...     None        None  None   None    None        None
# 3      ...     None        None  None   None    None        None
# 4      ...     None        None  None   None    None        None
# ...    ...      ...         ...   ...    ...     ...         ...
# 25974  ...     None        None  None   None    None        None
# 25975  ...     None        None  None   None    None        None
# 25976  ...     None        None  None   None    None        None
# 25977  ...     None        None  None   None    None        None
# 25978  ...     None        None  None   None    None        None
#
#                     league_name  country_name                home_team  \
# 0        Belgium Jupiler League       Belgium                 KRC Genk
# 1        Belgium Jupiler League       Belgium         SV Zulte-Waregem
# 2        Belgium Jupiler League       Belgium        KSV Cercle Brugge
# 3        Belgium Jupiler League       Belgium                 KAA Gent
# 4        Belgium Jupiler League       Belgium                      NaN
# ...                         ...           ...                      ...
# 25974  Switzerland Super League   Switzerland            FC St. Gallen
# 25975  Switzerland Super League   Switzerland                 FC Vaduz
# 25976  Switzerland Super League   Switzerland  Grasshopper Club Zürich
# 25977  Switzerland Super League   Switzerland                      NaN
# 25978  Switzerland Super League   Switzerland           BSC Young Boys
#
#                away_team
# 0           Beerschot AC
# 1       Sporting Lokeren
# 2         RSC Anderlecht
# 3              RAEC Mons
# 4      Standard de Liège
# ...                  ...
# 25974            FC Thun
# 25975          FC Luzern
# 25976            FC Sion
# 25977          FC Zürich
# 25978           FC Basel
#
# [25979 rows x 44 columns]

# %%
df_match=df_match[config.keep_match]
df_match.head()
# Out:
#               league_name country_name     season          home_team  \
# 0  Belgium Jupiler League      Belgium  2008/2009           KRC Genk
# 1  Belgium Jupiler League      Belgium  2008/2009   SV Zulte-Waregem
# 2  Belgium Jupiler League      Belgium  2008/2009  KSV Cercle Brugge
# 3  Belgium Jupiler League      Belgium  2008/2009           KAA Gent
# 4  Belgium Jupiler League      Belgium  2008/2009                NaN
#
#            away_team  home_team_goal  away_team_goal
# 0       Beerschot AC               1               1
# 1   Sporting Lokeren               0               0
# 2     RSC Anderlecht               0               3
# 3          RAEC Mons               5               0
# 4  Standard de Liège               1               3

# %%
df_match['total_goal']=df_match['home_team_goal']+df_match['away_team_goal']
df_match_high_score=df_match.sort_values(by='total_goal',ascending=False)
df_match_high_score
# Out:
# /tmp/ipykernel_38949/763770959.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_match['total_goal']=df_match['home_team_goal']+df_match['away_team_goal']
#                    league_name country_name     season  \
# 24247          Spain LIGA BBVA        Spain  2015/2016
# 20106  Scotland Premier League     Scotland  2009/2010
# 9210     Germany 1. Bundesliga      Germany  2012/2013
# 23443          Spain LIGA BBVA        Spain  2013/2014
# 24122          Spain LIGA BBVA        Spain  2014/2015
# ...                        ...          ...        ...
# 2340    England Premier League      England  2009/2010
# 23860          Spain LIGA BBVA        Spain  2014/2015
# 23861          Spain LIGA BBVA        Spain  2014/2015
# 23864          Spain LIGA BBVA        Spain  2014/2015
# 10763            Italy Serie A        Italy  2009/2010
#
#                        home_team       away_team  home_team_goal  \
# 24247             Real Madrid CF  Rayo Vallecano              10
# 20106                 Motherwell       Hibernian               6
# 9210            FC Bayern Munich    Hamburger SV               9
# 23443             Real Madrid CF      Sevilla FC               7
# 24122  RC Deportivo de La Coruña  Real Madrid CF               2
# ...                          ...             ...             ...
# 2340                  Stoke City     Aston Villa               0
# 23860                 Córdoba CF      Levante UD               0
# 23861                  Getafe CF    FC Barcelona               0
# 23864                 Sevilla FC        SD Eibar               0
# 10763                     Napoli         Palermo               0
#
#        away_team_goal  total_goal
# 24247               2          12
# 20106               6          12
# 9210                2          11
# 23443               3          10
# 24122               8          10
# ...               ...         ...
# 2340                0           0
# 23860               0           0
# 23861               0           0
# 23864               0           0
# 10763               0           0
#
# [25979 rows x 8 columns]

# %%
plt.figure(figsize=(10, 6))
plt.bar((df_match_high_score['home_team']+"vs"+df_match_high_score['home_team']).head().astype(str), df_match_high_score['total_goal'].head(), color='skyblue')


plt.xlabel('home team vs home team')
plt.ylabel(' total_goal')
plt.title('top les matchs avec les scores les plus élevés ')
plt.xticks(rotation=45)  

plt.tight_layout()
plt.show()

# %%
#les matchs marqués par un grand nombre de buts

# %%
high_gooal_matches=df_match[df_match['total_goal']>6]
high_gooal_matches
# Out:
#                     league_name country_name     season  \
# 56       Belgium Jupiler League      Belgium  2008/2009
# 76       Belgium Jupiler League      Belgium  2008/2009
# 111      Belgium Jupiler League      Belgium  2008/2009
# 157      Belgium Jupiler League      Belgium  2008/2009
# 297      Belgium Jupiler League      Belgium  2008/2009
# ...                         ...          ...        ...
# 25901  Switzerland Super League  Switzerland  2015/2016
# 25902  Switzerland Super League  Switzerland  2015/2016
# 25949  Switzerland Super League  Switzerland  2015/2016
# 25963  Switzerland Super League  Switzerland  2015/2016
# 25978  Switzerland Super League  Switzerland  2015/2016
#
#                      home_team      away_team  home_team_goal  away_team_goal  \
# 56                   RAEC Mons            NaN               5               2
# 76           KSV Cercle Brugge  KSV Roeselare               4               3
# 111         Sporting Charleroi       KAA Gent               2               5
# 157                   KRC Genk            NaN               4               3
# 297             RSC Anderlecht    KV Mechelen               7               1
# ...                        ...            ...             ...             ...
# 25901            FC St. Gallen       FC Basel               0               7
# 25902           BSC Young Boys       FC Vaduz               5               4
# 25949  Grasshopper Club Zürich            NaN               6               1
# 25963                FC Zürich      FC Luzern               2               5
# 25978           BSC Young Boys       FC Basel               4               3
#
#        total_goal
# 56              7
# 76              7
# 111             7
# 157             7
# 297             8
# ...           ...
# 25901           7
# 25902           9
# 25949           7
# 25963           7
# 25978           7
#
# [552 rows x 8 columns]

# %%
teams= list(df_team['team_long_name'].unique())
#teams

# %%
match_domicile_performence = df_match.groupby("home_team")['home_team_goal'].sum().reset_index()
display(match_domicile_performence)
match_exterieur_performence = df_match.groupby("away_team")['away_team_goal'].sum().reset_index()
display(match_exterieur_performence)


for team in teams[:1]:
    plt.figure(figsize=(10,5))


    plt.bar(match_domicile_performence[match_domicile_performence['home_team']==team]['home_team'], match_domicile_performence[match_domicile_performence['home_team']==team]['home_team_goal'], width=0.4, label='Home Goals', align='edge')
    plt.bar(match_exterieur_performence[match_exterieur_performence['away_team']==team]['away_team'], match_exterieur_performence[match_exterieur_performence['away_team']==team]['away_team_goal'], width=0.4, label='away Goals', align='edge')

    plt.xlabel('teams')
    plt.ylabel('goals')
    plt.title(" performance matchs joués à domicile et à l'extérieur")
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
#                     home_team  home_team_goal
# 0        1. FC Kaiserslautern              37
# 1                  1. FC Köln             116
# 2              1. FC Nürnberg             108
# 3             1. FSV Mainz 05             171
# 4                  AC Ajaccio              64
# ..                        ...             ...
# 280      Xerez Club Deportivo              20
# 281            Zagłębie Lubin             116
# 282         Zawisza Bydgoszcz              43
# 283  Évian Thonon Gaillard FC             105
# 284             Śląsk Wrocław             176
#
# [285 rows x 2 columns]
#                     away_team  away_team_goal
# 0        1. FC Kaiserslautern              35
# 1                  1. FC Köln             110
# 2              1. FC Nürnberg              85
# 3             1. FSV Mainz 05             149
# 4                  AC Ajaccio              52
# ..                        ...             ...
# 280      Xerez Club Deportivo              18
# 281            Zagłębie Lubin              91
# 282         Zawisza Bydgoszcz              32
# 283  Évian Thonon Gaillard FC              75
# 284             Śląsk Wrocław             142
#
# [285 rows x 2 columns]

# %% [markdown]
# #####  2) team

# %%
df_team
# Out:
#       id_team    team_long_name team_short_name  id_team_attribute  team_id  \
# 0       49119          FC Aarau             AAR                  1     9930
# 1       49119          FC Aarau             AAR                  2     9930
# 2       49119          FC Aarau             AAR                  3     9930
# 3       39393          Aberdeen             ABE                  4     8485
# 4       39393          Aberdeen             ABE                  5     8485
# ...       ...               ...             ...                ...      ...
# 1453        3  SV Zulte-Waregem             ZUL               1454    10000
# 1454        3  SV Zulte-Waregem             ZUL               1455    10000
# 1455        3  SV Zulte-Waregem             ZUL               1456    10000
# 1456        3  SV Zulte-Waregem             ZUL               1457    10000
# 1457        3  SV Zulte-Waregem             ZUL               1458    10000
#
#                      date  buildUpPlaySpeed buildUpPlaySpeedClass  \
# 0     2010-02-22 00:00:00                60              Balanced
# 1     2014-09-19 00:00:00                52              Balanced
# 2     2015-09-10 00:00:00                47              Balanced
# 3     2010-02-22 00:00:00                70                  Fast
# 4     2011-02-22 00:00:00                47              Balanced
# ...                   ...               ...                   ...
# 1453  2011-02-22 00:00:00                52              Balanced
# 1454  2012-02-22 00:00:00                54              Balanced
# 1455  2013-09-20 00:00:00                54              Balanced
# 1456  2014-09-19 00:00:00                54              Balanced
# 1457  2015-09-10 00:00:00                54              Balanced
#
#       buildUpPlayDribbling buildUpPlayDribblingClass  ...  \
# 0                      NaN                    Little  ...
# 1                     48.0                    Normal  ...
# 2                     41.0                    Normal  ...
# 3                      NaN                    Little  ...
# 4                      NaN                    Little  ...
# ...                    ...                       ...  ...
# 1453                   NaN                    Little  ...
# 1454                   NaN                    Little  ...
# 1455                   NaN                    Little  ...
# 1456                  42.0                    Normal  ...
# 1457                  42.0                    Normal  ...
#
#       chanceCreationShooting chanceCreationShootingClass  \
# 0                         55                      Normal
# 1                         64                      Normal
# 2                         64                      Normal
# 3                         70                        Lots
# 4                         52                      Normal
# ...                      ...                         ...
# 1453                      53                      Normal
# 1454                      50                      Normal
# 1455                      32                      Little
# 1456                      32                      Little
# 1457                      32                      Little
#
#      chanceCreationPositioningClass  defencePressure defencePressureClass  \
# 0                         Organised               50               Medium
# 1                         Organised               47               Medium
# 2                         Organised               47               Medium
# 3                         Organised               60               Medium
# 4                         Organised               47               Medium
# ...                             ...              ...                  ...
# 1453                      Organised               46               Medium
# 1454                      Organised               44               Medium
# 1455                      Organised               44               Medium
# 1456                      Organised               44               Medium
# 1457                      Organised               44               Medium
#
#       defenceAggression defenceAggressionClass  defenceTeamWidth  \
# 0                    55                  Press                45
# 1                    44                  Press                54
# 2                    44                  Press                54
# 3                    70                 Double                70
# 4                    47                  Press                52
# ...                 ...                    ...               ...
# 1453                 48                  Press                53
# 1454                 55                  Press                53
# 1455                 58                  Press                37
# 1456                 58                  Press                37
# 1457                 58                  Press                37
#
#      defenceTeamWidthClass defenceDefenderLineClass
# 0                   Normal                    Cover
# 1                   Normal                    Cover
# 2                   Normal                    Cover
# 3                     Wide                    Cover
# 4                   Normal                    Cover
# ...                    ...                      ...
# 1453                Normal                    Cover
# 1454                Normal                    Cover
# 1455                Normal                    Cover
# 1456                Normal                    Cover
# 1457                Normal                    Cover
#
# [1458 rows x 27 columns]

# %%
df_match
# Out:
#                     league_name country_name     season  \
# 0        Belgium Jupiler League      Belgium  2008/2009
# 1        Belgium Jupiler League      Belgium  2008/2009
# 2        Belgium Jupiler League      Belgium  2008/2009
# 3        Belgium Jupiler League      Belgium  2008/2009
# 4        Belgium Jupiler League      Belgium  2008/2009
# ...                         ...          ...        ...
# 25974  Switzerland Super League  Switzerland  2015/2016
# 25975  Switzerland Super League  Switzerland  2015/2016
# 25976  Switzerland Super League  Switzerland  2015/2016
# 25977  Switzerland Super League  Switzerland  2015/2016
# 25978  Switzerland Super League  Switzerland  2015/2016
#
#                      home_team          away_team  home_team_goal  \
# 0                     KRC Genk       Beerschot AC               1
# 1             SV Zulte-Waregem   Sporting Lokeren               0
# 2            KSV Cercle Brugge     RSC Anderlecht               0
# 3                     KAA Gent          RAEC Mons               5
# 4                          NaN  Standard de Liège               1
# ...                        ...                ...             ...
# 25974            FC St. Gallen            FC Thun               1
# 25975                 FC Vaduz          FC Luzern               1
# 25976  Grasshopper Club Zürich            FC Sion               2
# 25977                      NaN          FC Zürich               0
# 25978           BSC Young Boys           FC Basel               4
#
#        away_team_goal  total_goal
# 0                   1           2
# 1                   0           0
# 2                   3           3
# 3                   0           5
# 4                   3           4
# ...               ...         ...
# 25974               0           1
# 25975               2           3
# 25976               0           2
# 25977               0           0
# 25978               3           7
#
# [25979 rows x 8 columns]

# %%
#les équipes dominent dans chaque ligue

# %%
def get_team(group):
    return group.sort_values(by='total_goal',  ascending=False).iloc[0]
     

team_domine_league=(df_match.groupby(['league_name','home_team']).apply(get_team).reset_index(drop=True)).groupby('league_name').apply(get_team).reset_index(drop=True)
display(team_domine_league)


new_team_domine_league = team_domine_league.apply(lambda x: (x['league_name'], x['home_team']) if x['home_team_goal'] > x['away_team_goal'] else (x['league_name'], x['away_team']), axis=1)

t_d_l=pd.DataFrame(list(new_team_domine_league),columns=["league","team"])
display(t_d_l)


#new_team_domine_league = team_domine_league.apply(lambda x : x['league_name','home_team'] if x['home_team_goal'] > x['away_team_goal'] else  x['league_name','away_team'])
# Out:
# /tmp/ipykernel_38949/2672266389.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   team_domine_league=(df_match.groupby(['league_name','home_team']).apply(get_team).reset_index(drop=True)).groupby('league_name').apply(get_team).reset_index(drop=True)
# /tmp/ipykernel_38949/2672266389.py:5: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   team_domine_league=(df_match.groupby(['league_name','home_team']).apply(get_team).reset_index(drop=True)).groupby('league_name').apply(get_team).reset_index(drop=True)
#                  league_name country_name     season           home_team  \
# 0     Belgium Jupiler League      Belgium  2011/2012      Club Brugge KV
# 1     England Premier League      England  2012/2013             Arsenal
# 2             France Ligue 1       France  2009/2010  Olympique Lyonnais
# 3      Germany 1. Bundesliga      Germany  2012/2013    FC Bayern Munich
# 4              Italy Serie A        Italy  2011/2012               Inter
# 5     Netherlands Eredivisie  Netherlands  2010/2011                 PSV
# 6         Poland Ekstraklasa       Poland  2009/2010            Cracovia
# 7   Portugal Liga ZON Sagres     Portugal  2009/2010          SL Benfica
# 8    Scotland Premier League     Scotland  2009/2010          Motherwell
# 9            Spain LIGA BBVA        Spain  2015/2016      Real Madrid CF
# 10  Switzerland Super League  Switzerland  2015/2016      BSC Young Boys
#
#                  away_team  home_team_goal  away_team_goal  total_goal
# 0                 KRC Genk               4               5           9
# 1         Newcastle United               7               3          10
# 2   Olympique de Marseille               5               5          10
# 3             Hamburger SV               9               2          11
# 4                    Genoa               5               4           9
# 5                Feyenoord              10               0          10
# 6            Lechia Gdańsk               2               6           8
# 7          Vitória Setúbal               8               1           9
# 8                Hibernian               6               6          12
# 9           Rayo Vallecano              10               2          12
# 10                FC Vaduz               5               4           9
#                       league                    team
# 0     Belgium Jupiler League                KRC Genk
# 1     England Premier League                 Arsenal
# 2             France Ligue 1  Olympique de Marseille
# 3      Germany 1. Bundesliga        FC Bayern Munich
# 4              Italy Serie A                   Inter
# 5     Netherlands Eredivisie                     PSV
# 6         Poland Ekstraklasa           Lechia Gdańsk
# 7   Portugal Liga ZON Sagres              SL Benfica
# 8    Scotland Premier League               Hibernian
# 9            Spain LIGA BBVA          Real Madrid CF
# 10  Switzerland Super League          BSC Young Boys

# %%
display(df_team)
#print(df_team.columns.to_list())
# Out:
#       id_team    team_long_name team_short_name  id_team_attribute  team_id  \
# 0       49119          FC Aarau             AAR                  1     9930
# 1       49119          FC Aarau             AAR                  2     9930
# 2       49119          FC Aarau             AAR                  3     9930
# 3       39393          Aberdeen             ABE                  4     8485
# 4       39393          Aberdeen             ABE                  5     8485
# ...       ...               ...             ...                ...      ...
# 1453        3  SV Zulte-Waregem             ZUL               1454    10000
# 1454        3  SV Zulte-Waregem             ZUL               1455    10000
# 1455        3  SV Zulte-Waregem             ZUL               1456    10000
# 1456        3  SV Zulte-Waregem             ZUL               1457    10000
# 1457        3  SV Zulte-Waregem             ZUL               1458    10000
#
#                      date  buildUpPlaySpeed buildUpPlaySpeedClass  \
# 0     2010-02-22 00:00:00                60              Balanced
# 1     2014-09-19 00:00:00                52              Balanced
# 2     2015-09-10 00:00:00                47              Balanced
# 3     2010-02-22 00:00:00                70                  Fast
# 4     2011-02-22 00:00:00                47              Balanced
# ...                   ...               ...                   ...
# 1453  2011-02-22 00:00:00                52              Balanced
# 1454  2012-02-22 00:00:00                54              Balanced
# 1455  2013-09-20 00:00:00                54              Balanced
# 1456  2014-09-19 00:00:00                54              Balanced
# 1457  2015-09-10 00:00:00                54              Balanced
#
#       buildUpPlayDribbling buildUpPlayDribblingClass  ...  \
# 0                      NaN                    Little  ...
# 1                     48.0                    Normal  ...
# 2                     41.0                    Normal  ...
# 3                      NaN                    Little  ...
# 4                      NaN                    Little  ...
# ...                    ...                       ...  ...
# 1453                   NaN                    Little  ...
# 1454                   NaN                    Little  ...
# 1455                   NaN                    Little  ...
# 1456                  42.0                    Normal  ...
# 1457                  42.0                    Normal  ...
#
#       chanceCreationShooting chanceCreationShootingClass  \
# 0                         55                      Normal
# 1                         64                      Normal
# 2                         64                      Normal
# 3                         70                        Lots
# 4                         52                      Normal
# ...                      ...                         ...
# 1453                      53                      Normal
# 1454                      50                      Normal
# 1455                      32                      Little
# 1456                      32                      Little
# 1457                      32                      Little
#
#      chanceCreationPositioningClass  defencePressure defencePressureClass  \
# 0                         Organised               50               Medium
# 1                         Organised               47               Medium
# 2                         Organised               47               Medium
# 3                         Organised               60               Medium
# 4                         Organised               47               Medium
# ...                             ...              ...                  ...
# 1453                      Organised               46               Medium
# 1454                      Organised               44               Medium
# 1455                      Organised               44               Medium
# 1456                      Organised               44               Medium
# 1457                      Organised               44               Medium
#
#       defenceAggression defenceAggressionClass  defenceTeamWidth  \
# 0                    55                  Press                45
# 1                    44                  Press                54
# 2                    44                  Press                54
# 3                    70                 Double                70
# 4                    47                  Press                52
# ...                 ...                    ...               ...
# 1453                 48                  Press                53
# 1454                 55                  Press                53
# 1455                 58                  Press                37
# 1456                 58                  Press                37
# 1457                 58                  Press                37
#
#      defenceTeamWidthClass defenceDefenderLineClass
# 0                   Normal                    Cover
# 1                   Normal                    Cover
# 2                   Normal                    Cover
# 3                     Wide                    Cover
# 4                   Normal                    Cover
# ...                    ...                      ...
# 1453                Normal                    Cover
# 1454                Normal                    Cover
# 1455                Normal                    Cover
# 1456                Normal                    Cover
# 1457                Normal                    Cover
#
# [1458 rows x 27 columns]

# %%
# les équipes en termes de styles de jeu

# %%
def compare_team(group):
    return group[['buildUpPlaySpeed','chanceCreationPassing','defencePressure']].median()

df_compare_team=df_team.groupby('team_long_name').apply(compare_team).reset_index()
display(df_compare_team)
# Out:
# /tmp/ipykernel_38949/2826417745.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_compare_team=df_team.groupby('team_long_name').apply(compare_team).reset_index()
#                team_long_name  buildUpPlaySpeed  chanceCreationPassing  \
# 0        1. FC Kaiserslautern              48.5                   47.0
# 1                  1. FC Köln              58.5                   57.0
# 2              1. FC Nürnberg              45.5                   51.0
# 3             1. FSV Mainz 05              65.5                   55.0
# 4                  AC Ajaccio              59.0                   48.0
# ..                        ...               ...                    ...
# 280      Xerez Club Deportivo              50.0                   42.5
# 281            Zagłębie Lubin              33.0                   48.0
# 282         Zawisza Bydgoszcz              54.0                   56.5
# 283  Évian Thonon Gaillard FC              53.0                   52.0
# 284             Śląsk Wrocław              48.5                   48.0
#
#      defencePressure
# 0               44.0
# 1               43.0
# 2               45.0
# 3               52.5
# 4               38.0
# ..               ...
# 280             47.5
# 281             58.0
# 282             44.0
# 283             47.0
# 284             41.0
#
# [285 rows x 4 columns]

# %%
df_subset = df_compare_team.head(7)

# Positions for each team
x = np.arange(len(df_subset['team_long_name']))  

bar_width = 0.25

fig, ax = plt.subplots(figsize=(12, 6))
ax.bar(x - bar_width, df_subset['buildUpPlaySpeed'], width=bar_width, label='Build-Up Speed')
ax.bar(x, df_subset['chanceCreationPassing'], width=bar_width, label='Passing Accuracy')
ax.bar(x + bar_width, df_subset['defencePressure'], width=bar_width, label='Defensive Pressure')

ax.set_xlabel('Teams')
ax.set_ylabel('Values')
ax.set_title('les équipes en termes de styles de jeu')
ax.set_xticks(x)
ax.set_xticklabels(df_subset['team_long_name'], rotation=45)
ax.legend()

plt.tight_layout()
plt.show()
