# %% [markdown]
# # collect the data  and some minimal analyse

# %%
import sqlite3
import pandas as pd
from config.config import config

conn = sqlite3.connect(config.database_url)
query = "SELECT name FROM sqlite_master WHERE type='table';"
tables = pd.read_sql_query(query, conn)
print(tables.name.to_list())
# Out:
# ['sqlite_sequence', 'Player_Attributes', 'Player', 'Match', 'League', 'Country', 'Team', 'Team_Attributes']

# %%
for table in [ 'Player_Attributes', 'Player', 'Match', 'League', 'Country', 'Team', 'Team_Attributes'] :
    print(table)
    query1 = f"select * from {table};"
    display(pd.read_sql_query(query1,conn).info())
    print('-------------------------------------------')
# Out:
# Player_Attributes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183978 entries, 0 to 183977
# Data columns (total 42 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   183978 non-null  int64
#  1   player_fifa_api_id   183978 non-null  int64
#  2   player_api_id        183978 non-null  int64
#  3   date                 183978 non-null  object
#  4   overall_rating       183142 non-null  float64
#  5   potential            183142 non-null  float64
#  6   preferred_foot       183142 non-null  object
#  7   attacking_work_rate  180748 non-null  object
#  8   defensive_work_rate  183142 non-null  object
#  9   crossing             183142 non-null  float64
#  10  finishing            183142 non-null  float64
#  11  heading_accuracy     183142 non-null  float64
#  12  short_passing        183142 non-null  float64
#  13  volleys              181265 non-null  float64
#  14  dribbling            183142 non-null  float64
#  15  curve                181265 non-null  float64
#  16  free_kick_accuracy   183142 non-null  float64
#  17  long_passing         183142 non-null  float64
#  18  ball_control         183142 non-null  float64
#  19  acceleration         183142 non-null  float64
#  20  sprint_speed         183142 non-null  float64
#  21  agility              181265 non-null  float64
#  22  reactions            183142 non-null  float64
#  23  balance              181265 non-null  float64
#  24  shot_power           183142 non-null  float64
#  25  jumping              181265 non-null  float64
#  26  stamina              183142 non-null  float64
#  27  strength             183142 non-null  float64
#  28  long_shots           183142 non-null  float64
#  29  aggression           183142 non-null  float64
#  30  interceptions        183142 non-null  float64
#  31  positioning          183142 non-null  float64
#  32  vision               181265 non-null  float64
#  33  penalties            183142 non-null  float64
#  34  marking              183142 non-null  float64
#  35  standing_tackle      183142 non-null  float64
#  36  sliding_tackle       181265 non-null  float64
#  37  gk_diving            183142 non-null  float64
#  38  gk_handling          183142 non-null  float64
#  39  gk_kicking           183142 non-null  float64
#  40  gk_positioning       183142 non-null  float64
#  41  gk_reflexes          183142 non-null  float64
# dtypes: float64(35), int64(3), object(4)
# memory usage: 59.0+ MB
# None
# -------------------------------------------
# Player
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11060 entries, 0 to 11059
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  11060 non-null  int64
#  1   player_api_id       11060 non-null  int64
#  2   player_name         11060 non-null  object
#  3   player_fifa_api_id  11060 non-null  int64
#  4   birthday            11060 non-null  object
#  5   height              11060 non-null  float64
#  6   weight              11060 non-null  int64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 605.0+ KB
# None
# -------------------------------------------
# Match
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25979 entries, 0 to 25978
# Columns: 115 entries, id to BSA
# dtypes: float64(96), int64(9), object(10)
# memory usage: 22.8+ MB
# None
# -------------------------------------------
# League
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          11 non-null     int64
#  1   country_id  11 non-null     int64
#  2   name        11 non-null     object
# dtypes: int64(2), object(1)
# memory usage: 396.0+ bytes
# None
# -------------------------------------------
# Country
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      11 non-null     int64
#  1   name    11 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 308.0+ bytes
# None
# -------------------------------------------
# Team
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                299 non-null    int64
#  1   team_api_id       299 non-null    int64
#  2   team_fifa_api_id  288 non-null    float64
#  3   team_long_name    299 non-null    object
#  4   team_short_name   299 non-null    object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 11.8+ KB
# None
# -------------------------------------------
# Team_Attributes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458 entries, 0 to 1457
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              1458 non-null   int64
#  1   team_fifa_api_id                1458 non-null   int64
#  2   team_api_id                     1458 non-null   int64
#  3   date                            1458 non-null   object
#  4   buildUpPlaySpeed                1458 non-null   int64
#  5   buildUpPlaySpeedClass           1458 non-null   object
#  6   buildUpPlayDribbling            489 non-null    float64
#  7   buildUpPlayDribblingClass       1458 non-null   object
#  8   buildUpPlayPassing              1458 non-null   int64
#  9   buildUpPlayPassingClass         1458 non-null   object
#  10  buildUpPlayPositioningClass     1458 non-null   object
#  11  chanceCreationPassing           1458 non-null   int64
#  12  chanceCreationPassingClass      1458 non-null   object
#  13  chanceCreationCrossing          1458 non-null   int64
#  14  chanceCreationCrossingClass     1458 non-null   object
#  15  chanceCreationShooting          1458 non-null   int64
#  16  chanceCreationShootingClass     1458 non-null   object
#  17  chanceCreationPositioningClass  1458 non-null   object
#  18  defencePressure                 1458 non-null   int64
#  19  defencePressureClass            1458 non-null   object
#  20  defenceAggression               1458 non-null   int64
#  21  defenceAggressionClass          1458 non-null   object
#  22  defenceTeamWidth                1458 non-null   int64
#  23  defenceTeamWidthClass           1458 non-null   object
#  24  defenceDefenderLineClass        1458 non-null   object
# dtypes: float64(1), int64(11), object(13)
# memory usage: 284.9+ KB
# None
# -------------------------------------------

# %%
for table in [ 'Player_Attributes', 'Player', 'Match', 'League', 'Country', 'Team', 'Team_Attributes'] :
    print(table)
    query1 = f"select * from {table};"
    print(pd.read_sql_query(query1,conn).columns.to_list())
    print()
# Out:
# Player_Attributes
# ['id', 'player_fifa_api_id', 'player_api_id', 'date', 'overall_rating', 'potential', 'preferred_foot', 'attacking_work_rate', 'defensive_work_rate', 'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy', 'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'marking', 'standing_tackle', 'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes']
#
# Player
# ['id', 'player_api_id', 'player_name', 'player_fifa_api_id', 'birthday', 'height', 'weight']
#
# Match
# ['id', 'country_id', 'league_id', 'season', 'stage', 'date', 'match_api_id', 'home_team_api_id', 'away_team_api_id', 'home_team_goal', 'away_team_goal', 'home_player_X1', 'home_player_X2', 'home_player_X3', 'home_player_X4', 'home_player_X5', 'home_player_X6', 'home_player_X7', 'home_player_X8', 'home_player_X9', 'home_player_X10', 'home_player_X11', 'away_player_X1', 'away_player_X2', 'away_player_X3', 'away_player_X4', 'away_player_X5', 'away_player_X6', 'away_player_X7', 'away_player_X8', 'away_player_X9', 'away_player_X10', 'away_player_X11', 'home_player_Y1', 'home_player_Y2', 'home_player_Y3', 'home_player_Y4', 'home_player_Y5', 'home_player_Y6', 'home_player_Y7', 'home_player_Y8', 'home_player_Y9', 'home_player_Y10', 'home_player_Y11', 'away_player_Y1', 'away_player_Y2', 'away_player_Y3', 'away_player_Y4', 'away_player_Y5', 'away_player_Y6', 'away_player_Y7', 'away_player_Y8', 'away_player_Y9', 'away_player_Y10', 'away_player_Y11', 'home_player_1', 'home_player_2', 'home_player_3', 'home_player_4', 'home_player_5', 'home_player_6', 'home_player_7', 'home_player_8', 'home_player_9', 'home_player_10', 'home_player_11', 'away_player_1', 'away_player_2', 'away_player_3', 'away_player_4', 'away_player_5', 'away_player_6', 'away_player_7', 'away_player_8', 'away_player_9', 'away_player_10', 'away_player_11', 'goal', 'shoton', 'shotoff', 'foulcommit', 'card', 'cross', 'corner', 'possession', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'LBH', 'LBD', 'LBA', 'PSH', 'PSD', 'PSA', 'WHH', 'WHD', 'WHA', 'SJH', 'SJD', 'SJA', 'VCH', 'VCD', 'VCA', 'GBH', 'GBD', 'GBA', 'BSH', 'BSD', 'BSA']
#
# League
# ['id', 'country_id', 'name']
#
# Country
# ['id', 'name']
#
# Team
# ['id', 'team_api_id', 'team_fifa_api_id', 'team_long_name', 'team_short_name']
#
# Team_Attributes
# ['id', 'team_fifa_api_id', 'team_api_id', 'date', 'buildUpPlaySpeed', 'buildUpPlaySpeedClass', 'buildUpPlayDribbling', 'buildUpPlayDribblingClass', 'buildUpPlayPassing', 'buildUpPlayPassingClass', 'buildUpPlayPositioningClass', 'chanceCreationPassing', 'chanceCreationPassingClass', 'chanceCreationCrossing', 'chanceCreationCrossingClass', 'chanceCreationShooting', 'chanceCreationShootingClass', 'chanceCreationPositioningClass', 'defencePressure', 'defencePressureClass', 'defenceAggression', 'defenceAggressionClass', 'defenceTeamWidth', 'defenceTeamWidthClass', 'defenceDefenderLineClass']

# %%
df_player = pd.read_sql_query(config.player_query,conn)
display(df_player.head())
df_team = pd.read_sql_query(config.team_query,conn)
display(df_team.head())
df_country = pd.read_sql_query(config.country_query,conn)
display(df_country.head())
df_match = pd.read_sql_query(config.match_query,conn)
display(df_match.head())
# Out:
#    id  player_api_id         player_name  player_fifa_api_id  \
# 0   1         505942  Aaron Appindangoye              218353
# 1   1         505942  Aaron Appindangoye              218353
# 2   1         505942  Aaron Appindangoye              218353
# 3   1         505942  Aaron Appindangoye              218353
# 4   1         505942  Aaron Appindangoye              218353
#
#               birthday  height  weight  id  player_fifa_api_id  player_api_id  \
# 0  1992-02-29 00:00:00  182.88     187   1              218353         505942
# 1  1992-02-29 00:00:00  182.88     187   2              218353         505942
# 2  1992-02-29 00:00:00  182.88     187   3              218353         505942
# 3  1992-02-29 00:00:00  182.88     187   4              218353         505942
# 4  1992-02-29 00:00:00  182.88     187   5              218353         505942
#
#    ... vision  penalties  marking standing_tackle sliding_tackle gk_diving  \
# 0  ...   54.0       48.0     65.0            69.0           69.0       6.0
# 1  ...   54.0       48.0     65.0            69.0           69.0       6.0
# 2  ...   54.0       48.0     65.0            66.0           69.0       6.0
# 3  ...   53.0       47.0     62.0            63.0           66.0       5.0
# 4  ...   53.0       47.0     62.0            63.0           66.0       5.0
#
#    gk_handling  gk_kicking  gk_positioning  gk_reflexes
# 0         11.0        10.0             8.0          8.0
# 1         11.0        10.0             8.0          8.0
# 2         11.0        10.0             8.0          8.0
# 3         10.0         9.0             7.0          7.0
# 4         10.0         9.0             7.0          7.0
#
# [5 rows x 49 columns]
#       id  team_api_id  team_fifa_api_id team_long_name team_short_name  id  \
# 0  49119         9930               434       FC Aarau             AAR   1
# 1  49119         9930               434       FC Aarau             AAR   2
# 2  49119         9930               434       FC Aarau             AAR   3
# 3  39393         8485                77       Aberdeen             ABE   4
# 4  39393         8485                77       Aberdeen             ABE   5
#
#    team_fifa_api_id  team_api_id                 date  buildUpPlaySpeed  ...  \
# 0               434         9930  2010-02-22 00:00:00                60  ...
# 1               434         9930  2014-09-19 00:00:00                52  ...
# 2               434         9930  2015-09-10 00:00:00                47  ...
# 3                77         8485  2010-02-22 00:00:00                70  ...
# 4                77         8485  2011-02-22 00:00:00                47  ...
#
#   chanceCreationShooting  chanceCreationShootingClass  \
# 0                     55                       Normal
# 1                     64                       Normal
# 2                     64                       Normal
# 3                     70                         Lots
# 4                     52                       Normal
#
#   chanceCreationPositioningClass  defencePressure defencePressureClass  \
# 0                      Organised               50               Medium
# 1                      Organised               47               Medium
# 2                      Organised               47               Medium
# 3                      Organised               60               Medium
# 4                      Organised               47               Medium
#
#   defenceAggression  defenceAggressionClass defenceTeamWidth  \
# 0                55                   Press               45
# 1                44                   Press               54
# 2                44                   Press               54
# 3                70                  Double               70
# 4                47                   Press               52
#
#    defenceTeamWidthClass defenceDefenderLineClass
# 0                 Normal                    Cover
# 1                 Normal                    Cover
# 2                 Normal                    Cover
# 3                   Wide                    Cover
# 4                 Normal                    Cover
#
# [5 rows x 30 columns]
#       id  country_id                    name     id     name
# 0      1           1  Belgium Jupiler League      1  Belgium
# 1   1729        1729  England Premier League   1729  England
# 2   4769        4769          France Ligue 1   4769   France
# 3   7809        7809   Germany 1. Bundesliga   7809  Germany
# 4  10257       10257           Italy Serie A  10257    Italy
#    id  country_id  league_id     season  stage                 date  \
# 0   1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1   2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2   3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3   4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4   5           1          1  2008/2009      1  2008-08-16 00:00:00
#
#    match_api_id  home_team_api_id  away_team_api_id  home_team_goal  ...  \
# 0        492473              9987              9993               1  ...
# 1        492474             10000              9994               0  ...
# 2        492475              9984              8635               0  ...
# 3        492476              9991              9998               5  ...
# 4        492477              7947              9985               1  ...
#
#     SJA   VCH   VCD   VCA   GBH   GBD   GBA   BSH   BSD   BSA
# 0  4.00  1.65  3.40  4.50  1.78  3.25  4.00  1.73  3.40  4.20
# 1  3.80  2.00  3.25  3.25  1.85  3.25  3.75  1.91  3.25  3.60
# 2  2.50  2.35  3.25  2.65  2.50  3.20  2.50  2.30  3.20  2.75
# 3  7.50  1.45  3.75  6.50  1.50  3.75  5.50  1.44  3.75  6.50
# 4  1.73  4.50  3.40  1.65  4.50  3.50  1.65  4.75  3.30  1.67
#
# [5 rows x 115 columns]

# %% [markdown]
# # work on table 1 : player

# %%
#print(df_player.columns[7])
print(df_player.columns.to_list())
df_player.columns=['id_player', 'player_api_id', 'player_name', 'player_fifa_api_id', 'birthday', 'height', 'weight', 'id_attribute', 'player_fifa_api_id', 'player_id', 'date', 'overall_rating', 'potential', 'preferred_foot', 'attacking_work_rate', 'defensive_work_rate', 'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy', 'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'marking', 'standing_tackle', 'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes']

print(df_player.columns.to_list())

df_player.drop(config.drop_player, axis=1,inplace=True)
# Out:
# ['id', 'player_api_id', 'player_name', 'player_fifa_api_id', 'birthday', 'height', 'weight', 'id', 'player_fifa_api_id', 'player_api_id', 'date', 'overall_rating', 'potential', 'preferred_foot', 'attacking_work_rate', 'defensive_work_rate', 'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy', 'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'marking', 'standing_tackle', 'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes']
# ['id_player', 'player_api_id', 'player_name', 'player_fifa_api_id', 'birthday', 'height', 'weight', 'id_attribute', 'player_fifa_api_id', 'player_id', 'date', 'overall_rating', 'potential', 'preferred_foot', 'attacking_work_rate', 'defensive_work_rate', 'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy', 'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina', 'strength', 'long_shots', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'marking', 'standing_tackle', 'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes']

# %%
df_player.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183978 entries, 0 to 183977
# Data columns (total 46 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id_player            183978 non-null  int64
#  1   player_name          183978 non-null  object
#  2   birthday             183978 non-null  object
#  3   height               183978 non-null  float64
#  4   weight               183978 non-null  int64
#  5   id_attribute         183978 non-null  int64
#  6   player_id            183978 non-null  int64
#  7   date                 183978 non-null  object
#  8   overall_rating       183142 non-null  float64
#  9   potential            183142 non-null  float64
#  10  preferred_foot       183142 non-null  object
#  11  attacking_work_rate  180748 non-null  object
#  12  defensive_work_rate  183142 non-null  object
#  13  crossing             183142 non-null  float64
#  14  finishing            183142 non-null  float64
#  15  heading_accuracy     183142 non-null  float64
#  16  short_passing        183142 non-null  float64
#  17  volleys              181265 non-null  float64
#  18  dribbling            183142 non-null  float64
#  19  curve                181265 non-null  float64
#  20  free_kick_accuracy   183142 non-null  float64
#  21  long_passing         183142 non-null  float64
#  22  ball_control         183142 non-null  float64
#  23  acceleration         183142 non-null  float64
#  24  sprint_speed         183142 non-null  float64
#  25  agility              181265 non-null  float64
#  26  reactions            183142 non-null  float64
#  27  balance              181265 non-null  float64
#  28  shot_power           183142 non-null  float64
#  29  jumping              181265 non-null  float64
#  30  stamina              183142 non-null  float64
#  31  strength             183142 non-null  float64
#  32  long_shots           183142 non-null  float64
#  33  aggression           183142 non-null  float64
#  34  interceptions        183142 non-null  float64
#  35  positioning          183142 non-null  float64
#  36  vision               181265 non-null  float64
#  37  penalties            183142 non-null  float64
#  38  marking              183142 non-null  float64
#  39  standing_tackle      183142 non-null  float64
#  40  sliding_tackle       181265 non-null  float64
#  41  gk_diving            183142 non-null  float64
#  42  gk_handling          183142 non-null  float64
#  43  gk_kicking           183142 non-null  float64
#  44  gk_positioning       183142 non-null  float64
#  45  gk_reflexes          183142 non-null  float64
# dtypes: float64(36), int64(4), object(6)
# memory usage: 64.6+ MB

# %% [markdown]
# # work on table 2 : team

# %%
print(df_team.columns.to_list())
df_team.columns  = ['id_team', 'team_api_id', 'team_fifa_api_id', 'team_long_name', 'team_short_name', 'id_team_attribute', 'team_fifa_api_id', 'team_id', 'date', 'buildUpPlaySpeed', 'buildUpPlaySpeedClass', 'buildUpPlayDribbling', 'buildUpPlayDribblingClass', 'buildUpPlayPassing', 'buildUpPlayPassingClass', 'buildUpPlayPositioningClass', 'chanceCreationPassing', 'chanceCreationPassingClass', 'chanceCreationCrossing', 'chanceCreationCrossingClass', 'chanceCreationShooting', 'chanceCreationShootingClass', 'chanceCreationPositioningClass', 'defencePressure', 'defencePressureClass', 'defenceAggression', 'defenceAggressionClass', 'defenceTeamWidth', 'defenceTeamWidthClass', 'defenceDefenderLineClass']
df_team.drop(config.drop_team, axis=1,inplace=True)
df_team.drop(df_team.columns[1],axis=1,inplace=True)
print(df_team.columns.to_list())
# Out:
# ['id', 'team_api_id', 'team_fifa_api_id', 'team_long_name', 'team_short_name', 'id', 'team_fifa_api_id', 'team_api_id', 'date', 'buildUpPlaySpeed', 'buildUpPlaySpeedClass', 'buildUpPlayDribbling', 'buildUpPlayDribblingClass', 'buildUpPlayPassing', 'buildUpPlayPassingClass', 'buildUpPlayPositioningClass', 'chanceCreationPassing', 'chanceCreationPassingClass', 'chanceCreationCrossing', 'chanceCreationCrossingClass', 'chanceCreationShooting', 'chanceCreationShootingClass', 'chanceCreationPositioningClass', 'defencePressure', 'defencePressureClass', 'defenceAggression', 'defenceAggressionClass', 'defenceTeamWidth', 'defenceTeamWidthClass', 'defenceDefenderLineClass']
# ['id_team', 'team_long_name', 'team_short_name', 'id_team_attribute', 'team_id', 'date', 'buildUpPlaySpeed', 'buildUpPlaySpeedClass', 'buildUpPlayDribbling', 'buildUpPlayDribblingClass', 'buildUpPlayPassing', 'buildUpPlayPassingClass', 'buildUpPlayPositioningClass', 'chanceCreationPassing', 'chanceCreationPassingClass', 'chanceCreationCrossing', 'chanceCreationCrossingClass', 'chanceCreationShooting', 'chanceCreationShootingClass', 'chanceCreationPositioningClass', 'defencePressure', 'defencePressureClass', 'defenceAggression', 'defenceAggressionClass', 'defenceTeamWidth', 'defenceTeamWidthClass', 'defenceDefenderLineClass']

# %%
df_team.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458 entries, 0 to 1457
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id_team                         1458 non-null   int64
#  1   team_long_name                  1458 non-null   object
#  2   team_short_name                 1458 non-null   object
#  3   id_team_attribute               1458 non-null   int64
#  4   team_id                         1458 non-null   int64
#  5   date                            1458 non-null   object
#  6   buildUpPlaySpeed                1458 non-null   int64
#  7   buildUpPlaySpeedClass           1458 non-null   object
#  8   buildUpPlayDribbling            489 non-null    float64
#  9   buildUpPlayDribblingClass       1458 non-null   object
#  10  buildUpPlayPassing              1458 non-null   int64
#  11  buildUpPlayPassingClass         1458 non-null   object
#  12  buildUpPlayPositioningClass     1458 non-null   object
#  13  chanceCreationPassing           1458 non-null   int64
#  14  chanceCreationPassingClass      1458 non-null   object
#  15  chanceCreationCrossing          1458 non-null   int64
#  16  chanceCreationCrossingClass     1458 non-null   object
#  17  chanceCreationShooting          1458 non-null   int64
#  18  chanceCreationShootingClass     1458 non-null   object
#  19  chanceCreationPositioningClass  1458 non-null   object
#  20  defencePressure                 1458 non-null   int64
#  21  defencePressureClass            1458 non-null   object
#  22  defenceAggression               1458 non-null   int64
#  23  defenceAggressionClass          1458 non-null   object
#  24  defenceTeamWidth                1458 non-null   int64
#  25  defenceTeamWidthClass           1458 non-null   object
#  26  defenceDefenderLineClass        1458 non-null   object
# dtypes: float64(1), int64(11), object(15)
# memory usage: 307.7+ KB

# %% [markdown]
# # work on table 3 : country

# %%
df_country.columns=['id','country_id','league_name','country_id','country_name']

# %%
df_country.drop(config.drop_country,axis=1,inplace=True)
df_country
# Out:
#        id               league_name country_name
# 0       1    Belgium Jupiler League      Belgium
# 1    1729    England Premier League      England
# 2    4769            France Ligue 1       France
# 3    7809     Germany 1. Bundesliga      Germany
# 4   10257             Italy Serie A        Italy
# 5   13274    Netherlands Eredivisie  Netherlands
# 6   15722        Poland Ekstraklasa       Poland
# 7   17642  Portugal Liga ZON Sagres     Portugal
# 8   19694   Scotland Premier League     Scotland
# 9   21518           Spain LIGA BBVA        Spain
# 10  24558  Switzerland Super League  Switzerland

# %% [markdown]
# # work on table 4 : match

# %%
print(df_match.columns.to_list())
print(len(df_match.columns.to_list()))

df_match.drop(config.drop_match,axis=1,inplace=True)
print(df_match.columns.to_list())
print(len(df_match.columns.to_list()))
# Out:
# ['id', 'country_id', 'league_id', 'season', 'stage', 'date', 'match_api_id', 'home_team_api_id', 'away_team_api_id', 'home_team_goal', 'away_team_goal', 'home_player_X1', 'home_player_X2', 'home_player_X3', 'home_player_X4', 'home_player_X5', 'home_player_X6', 'home_player_X7', 'home_player_X8', 'home_player_X9', 'home_player_X10', 'home_player_X11', 'away_player_X1', 'away_player_X2', 'away_player_X3', 'away_player_X4', 'away_player_X5', 'away_player_X6', 'away_player_X7', 'away_player_X8', 'away_player_X9', 'away_player_X10', 'away_player_X11', 'home_player_Y1', 'home_player_Y2', 'home_player_Y3', 'home_player_Y4', 'home_player_Y5', 'home_player_Y6', 'home_player_Y7', 'home_player_Y8', 'home_player_Y9', 'home_player_Y10', 'home_player_Y11', 'away_player_Y1', 'away_player_Y2', 'away_player_Y3', 'away_player_Y4', 'away_player_Y5', 'away_player_Y6', 'away_player_Y7', 'away_player_Y8', 'away_player_Y9', 'away_player_Y10', 'away_player_Y11', 'home_player_1', 'home_player_2', 'home_player_3', 'home_player_4', 'home_player_5', 'home_player_6', 'home_player_7', 'home_player_8', 'home_player_9', 'home_player_10', 'home_player_11', 'away_player_1', 'away_player_2', 'away_player_3', 'away_player_4', 'away_player_5', 'away_player_6', 'away_player_7', 'away_player_8', 'away_player_9', 'away_player_10', 'away_player_11', 'goal', 'shoton', 'shotoff', 'foulcommit', 'card', 'cross', 'corner', 'possession', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'LBH', 'LBD', 'LBA', 'PSH', 'PSD', 'PSA', 'WHH', 'WHD', 'WHA', 'SJH', 'SJD', 'SJA', 'VCH', 'VCD', 'VCA', 'GBH', 'GBD', 'GBA', 'BSH', 'BSD', 'BSA']
# 115
# ['id', 'country_id', 'season', 'stage', 'date', 'match_api_id', 'home_team_api_id', 'away_team_api_id', 'home_team_goal', 'away_team_goal', 'home_player_1', 'home_player_2', 'home_player_3', 'home_player_4', 'home_player_5', 'home_player_6', 'home_player_7', 'home_player_8', 'home_player_9', 'home_player_10', 'home_player_11', 'away_player_1', 'away_player_2', 'away_player_3', 'away_player_4', 'away_player_5', 'away_player_6', 'away_player_7', 'away_player_8', 'away_player_9', 'away_player_10', 'away_player_11', 'goal', 'shoton', 'shotoff', 'foulcommit', 'card', 'cross', 'corner', 'possession']
# 40

# %%
df_match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25979 entries, 0 to 25978
# Data columns (total 40 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                25979 non-null  int64
#  1   country_id        25979 non-null  int64
#  2   season            25979 non-null  object
#  3   stage             25979 non-null  int64
#  4   date              25979 non-null  object
#  5   match_api_id      25979 non-null  int64
#  6   home_team_api_id  25979 non-null  int64
#  7   away_team_api_id  25979 non-null  int64
#  8   home_team_goal    25979 non-null  int64
#  9   away_team_goal    25979 non-null  int64
#  10  home_player_1     24755 non-null  float64
#  11  home_player_2     24664 non-null  float64
#  12  home_player_3     24698 non-null  float64
#  13  home_player_4     24656 non-null  float64
#  14  home_player_5     24663 non-null  float64
#  15  home_player_6     24654 non-null  float64
#  16  home_player_7     24752 non-null  float64
#  17  home_player_8     24670 non-null  float64
#  18  home_player_9     24706 non-null  float64
#  19  home_player_10    24543 non-null  float64
#  20  home_player_11    24424 non-null  float64
#  21  away_player_1     24745 non-null  float64
#  22  away_player_2     24701 non-null  float64
#  23  away_player_3     24686 non-null  float64
#  24  away_player_4     24658 non-null  float64
#  25  away_player_5     24644 non-null  float64
#  26  away_player_6     24666 non-null  float64
#  27  away_player_7     24744 non-null  float64
#  28  away_player_8     24638 non-null  float64
#  29  away_player_9     24651 non-null  float64
#  30  away_player_10    24538 non-null  float64
#  31  away_player_11    24425 non-null  float64
#  32  goal              14217 non-null  object
#  33  shoton            14217 non-null  object
#  34  shotoff           14217 non-null  object
#  35  foulcommit        14217 non-null  object
#  36  card              14217 non-null  object
#  37  cross             14217 non-null  object
#  38  corner            14217 non-null  object
#  39  possession        14217 non-null  object
# dtypes: float64(22), int64(8), object(10)
# memory usage: 7.9+ MB

# %% [markdown]
# # make shure the table are correct  so we can join them with match

# %%
df_country
# Out:
#        id               league_name country_name
# 0       1    Belgium Jupiler League      Belgium
# 1    1729    England Premier League      England
# 2    4769            France Ligue 1       France
# 3    7809     Germany 1. Bundesliga      Germany
# 4   10257             Italy Serie A        Italy
# 5   13274    Netherlands Eredivisie  Netherlands
# 6   15722        Poland Ekstraklasa       Poland
# 7   17642  Portugal Liga ZON Sagres     Portugal
# 8   19694   Scotland Premier League     Scotland
# 9   21518           Spain LIGA BBVA        Spain
# 10  24558  Switzerland Super League  Switzerland

# %%
display(df_match)
# Out:
#           id  country_id     season  stage                 date  match_api_id  \
# 0          1           1  2008/2009      1  2008-08-17 00:00:00        492473
# 1          2           1  2008/2009      1  2008-08-16 00:00:00        492474
# 2          3           1  2008/2009      1  2008-08-16 00:00:00        492475
# 3          4           1  2008/2009      1  2008-08-17 00:00:00        492476
# 4          5           1  2008/2009      1  2008-08-16 00:00:00        492477
# ...      ...         ...        ...    ...                  ...           ...
# 25974  25975       24558  2015/2016      9  2015-09-22 00:00:00       1992091
# 25975  25976       24558  2015/2016      9  2015-09-23 00:00:00       1992092
# 25976  25977       24558  2015/2016      9  2015-09-23 00:00:00       1992093
# 25977  25978       24558  2015/2016      9  2015-09-22 00:00:00       1992094
# 25978  25979       24558  2015/2016      9  2015-09-23 00:00:00       1992095
#
#        home_team_api_id  away_team_api_id  home_team_goal  away_team_goal  \
# 0                  9987              9993               1               1
# 1                 10000              9994               0               0
# 2                  9984              8635               0               3
# 3                  9991              9998               5               0
# 4                  7947              9985               1               3
# ...                 ...               ...             ...             ...
# 25974             10190             10191               1               0
# 25975              9824             10199               1               2
# 25976              9956             10179               2               0
# 25977              7896             10243               0               0
# 25978             10192              9931               4               3
#
#        ...  away_player_10  away_player_11  goal  shoton  shotoff  foulcommit  \
# 0      ...             NaN             NaN  None    None     None        None
# 1      ...             NaN             NaN  None    None     None        None
# 2      ...             NaN             NaN  None    None     None        None
# 3      ...             NaN             NaN  None    None     None        None
# 4      ...             NaN             NaN  None    None     None        None
# ...    ...             ...             ...   ...     ...      ...         ...
# 25974  ...        232110.0        289732.0  None    None     None        None
# 25975  ...         34082.0         95257.0  None    None     None        None
# 25976  ...        451335.0        275122.0  None    None     None        None
# 25977  ...         92252.0        194532.0  None    None     None        None
# 25978  ...         41726.0        527103.0  None    None     None        None
#
#        card  cross  corner  possession
# 0      None   None    None        None
# 1      None   None    None        None
# 2      None   None    None        None
# 3      None   None    None        None
# 4      None   None    None        None
# ...     ...    ...     ...         ...
# 25974  None   None    None        None
# 25975  None   None    None        None
# 25976  None   None    None        None
# 25977  None   None    None        None
# 25978  None   None    None        None
#
# [25979 rows x 40 columns]

# %%
df_player
# Out:
#         id_player         player_name             birthday  height  weight  \
# 0               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 1               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 2               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 3               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 4               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# ...           ...                 ...                  ...     ...     ...
# 183973      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
# 183974      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
# 183975      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
# 183976      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
# 183977      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
#
#         id_attribute  player_id                 date  overall_rating  \
# 0                  1     505942  2016-02-18 00:00:00            67.0
# 1                  2     505942  2015-11-19 00:00:00            67.0
# 2                  3     505942  2015-09-21 00:00:00            62.0
# 3                  4     505942  2015-03-20 00:00:00            61.0
# 4                  5     505942  2007-02-22 00:00:00            61.0
# ...              ...        ...                  ...             ...
# 183973        183974      39902  2009-08-30 00:00:00            83.0
# 183974        183975      39902  2009-02-22 00:00:00            78.0
# 183975        183976      39902  2008-08-30 00:00:00            77.0
# 183976        183977      39902  2007-08-30 00:00:00            78.0
# 183977        183978      39902  2007-02-22 00:00:00            80.0
#
#         potential  ... vision penalties marking  standing_tackle  \
# 0            71.0  ...   54.0      48.0    65.0             69.0
# 1            71.0  ...   54.0      48.0    65.0             69.0
# 2            66.0  ...   54.0      48.0    65.0             66.0
# 3            65.0  ...   53.0      47.0    62.0             63.0
# 4            65.0  ...   53.0      47.0    62.0             63.0
# ...           ...  ...    ...       ...     ...              ...
# 183973       85.0  ...   88.0      83.0    22.0             31.0
# 183974       80.0  ...   88.0      70.0    32.0             31.0
# 183975       80.0  ...   88.0      70.0    32.0             31.0
# 183976       81.0  ...   88.0      53.0    28.0             32.0
# 183977       81.0  ...   88.0      53.0    38.0             32.0
#
#         sliding_tackle  gk_diving  gk_handling  gk_kicking  gk_positioning  \
# 0                 69.0        6.0         11.0        10.0             8.0
# 1                 69.0        6.0         11.0        10.0             8.0
# 2                 69.0        6.0         11.0        10.0             8.0
# 3                 66.0        5.0         10.0         9.0             7.0
# 4                 66.0        5.0         10.0         9.0             7.0
# ...                ...        ...          ...         ...             ...
# 183973            30.0        9.0         20.0        84.0            20.0
# 183974            30.0        9.0         20.0        73.0            20.0
# 183975            30.0        9.0         20.0        73.0            20.0
# 183976            30.0        9.0         20.0        73.0            20.0
# 183977            30.0        9.0          9.0        78.0             7.0
#
#         gk_reflexes
# 0               8.0
# 1               8.0
# 2               8.0
# 3               7.0
# 4               7.0
# ...             ...
# 183973         20.0
# 183974         20.0
# 183975         20.0
# 183976         20.0
# 183977         15.0
#
# [183978 rows x 46 columns]

# %%
df_team
# Out:
#       id_team    team_long_name team_short_name  id_team_attribute  team_id  \
# 0       49119          FC Aarau             AAR                  1     9930
# 1       49119          FC Aarau             AAR                  2     9930
# 2       49119          FC Aarau             AAR                  3     9930
# 3       39393          Aberdeen             ABE                  4     8485
# 4       39393          Aberdeen             ABE                  5     8485
# ...       ...               ...             ...                ...      ...
# 1453        3  SV Zulte-Waregem             ZUL               1454    10000
# 1454        3  SV Zulte-Waregem             ZUL               1455    10000
# 1455        3  SV Zulte-Waregem             ZUL               1456    10000
# 1456        3  SV Zulte-Waregem             ZUL               1457    10000
# 1457        3  SV Zulte-Waregem             ZUL               1458    10000
#
#                      date  buildUpPlaySpeed buildUpPlaySpeedClass  \
# 0     2010-02-22 00:00:00                60              Balanced
# 1     2014-09-19 00:00:00                52              Balanced
# 2     2015-09-10 00:00:00                47              Balanced
# 3     2010-02-22 00:00:00                70                  Fast
# 4     2011-02-22 00:00:00                47              Balanced
# ...                   ...               ...                   ...
# 1453  2011-02-22 00:00:00                52              Balanced
# 1454  2012-02-22 00:00:00                54              Balanced
# 1455  2013-09-20 00:00:00                54              Balanced
# 1456  2014-09-19 00:00:00                54              Balanced
# 1457  2015-09-10 00:00:00                54              Balanced
#
#       buildUpPlayDribbling buildUpPlayDribblingClass  ...  \
# 0                      NaN                    Little  ...
# 1                     48.0                    Normal  ...
# 2                     41.0                    Normal  ...
# 3                      NaN                    Little  ...
# 4                      NaN                    Little  ...
# ...                    ...                       ...  ...
# 1453                   NaN                    Little  ...
# 1454                   NaN                    Little  ...
# 1455                   NaN                    Little  ...
# 1456                  42.0                    Normal  ...
# 1457                  42.0                    Normal  ...
#
#       chanceCreationShooting chanceCreationShootingClass  \
# 0                         55                      Normal
# 1                         64                      Normal
# 2                         64                      Normal
# 3                         70                        Lots
# 4                         52                      Normal
# ...                      ...                         ...
# 1453                      53                      Normal
# 1454                      50                      Normal
# 1455                      32                      Little
# 1456                      32                      Little
# 1457                      32                      Little
#
#      chanceCreationPositioningClass  defencePressure defencePressureClass  \
# 0                         Organised               50               Medium
# 1                         Organised               47               Medium
# 2                         Organised               47               Medium
# 3                         Organised               60               Medium
# 4                         Organised               47               Medium
# ...                             ...              ...                  ...
# 1453                      Organised               46               Medium
# 1454                      Organised               44               Medium
# 1455                      Organised               44               Medium
# 1456                      Organised               44               Medium
# 1457                      Organised               44               Medium
#
#       defenceAggression defenceAggressionClass  defenceTeamWidth  \
# 0                    55                  Press                45
# 1                    44                  Press                54
# 2                    44                  Press                54
# 3                    70                 Double                70
# 4                    47                  Press                52
# ...                 ...                    ...               ...
# 1453                 48                  Press                53
# 1454                 55                  Press                53
# 1455                 58                  Press                37
# 1456                 58                  Press                37
# 1457                 58                  Press                37
#
#      defenceTeamWidthClass defenceDefenderLineClass
# 0                   Normal                    Cover
# 1                   Normal                    Cover
# 2                   Normal                    Cover
# 3                     Wide                    Cover
# 4                   Normal                    Cover
# ...                    ...                      ...
# 1453                Normal                    Cover
# 1454                Normal                    Cover
# 1455                Normal                    Cover
# 1456                Normal                    Cover
# 1457                Normal                    Cover
#
# [1458 rows x 27 columns]

# %% [markdown]
# # cleaning the dataframe  and this what will be inside the function

# %% [markdown]
# ## match , country , team dataframe

# %%
df_country
# Out:
#        id               league_name country_name
# 0       1    Belgium Jupiler League      Belgium
# 1    1729    England Premier League      England
# 2    4769            France Ligue 1       France
# 3    7809     Germany 1. Bundesliga      Germany
# 4   10257             Italy Serie A        Italy
# 5   13274    Netherlands Eredivisie  Netherlands
# 6   15722        Poland Ekstraklasa       Poland
# 7   17642  Portugal Liga ZON Sagres     Portugal
# 8   19694   Scotland Premier League     Scotland
# 9   21518           Spain LIGA BBVA        Spain
# 10  24558  Switzerland Super League  Switzerland

# %%
df_team
# Out:
#       id_team    team_long_name team_short_name  id_team_attribute  team_id  \
# 0       49119          FC Aarau             AAR                  1     9930
# 1       49119          FC Aarau             AAR                  2     9930
# 2       49119          FC Aarau             AAR                  3     9930
# 3       39393          Aberdeen             ABE                  4     8485
# 4       39393          Aberdeen             ABE                  5     8485
# ...       ...               ...             ...                ...      ...
# 1453        3  SV Zulte-Waregem             ZUL               1454    10000
# 1454        3  SV Zulte-Waregem             ZUL               1455    10000
# 1455        3  SV Zulte-Waregem             ZUL               1456    10000
# 1456        3  SV Zulte-Waregem             ZUL               1457    10000
# 1457        3  SV Zulte-Waregem             ZUL               1458    10000
#
#                      date  buildUpPlaySpeed buildUpPlaySpeedClass  \
# 0     2010-02-22 00:00:00                60              Balanced
# 1     2014-09-19 00:00:00                52              Balanced
# 2     2015-09-10 00:00:00                47              Balanced
# 3     2010-02-22 00:00:00                70                  Fast
# 4     2011-02-22 00:00:00                47              Balanced
# ...                   ...               ...                   ...
# 1453  2011-02-22 00:00:00                52              Balanced
# 1454  2012-02-22 00:00:00                54              Balanced
# 1455  2013-09-20 00:00:00                54              Balanced
# 1456  2014-09-19 00:00:00                54              Balanced
# 1457  2015-09-10 00:00:00                54              Balanced
#
#       buildUpPlayDribbling buildUpPlayDribblingClass  ...  \
# 0                      NaN                    Little  ...
# 1                     48.0                    Normal  ...
# 2                     41.0                    Normal  ...
# 3                      NaN                    Little  ...
# 4                      NaN                    Little  ...
# ...                    ...                       ...  ...
# 1453                   NaN                    Little  ...
# 1454                   NaN                    Little  ...
# 1455                   NaN                    Little  ...
# 1456                  42.0                    Normal  ...
# 1457                  42.0                    Normal  ...
#
#       chanceCreationShooting chanceCreationShootingClass  \
# 0                         55                      Normal
# 1                         64                      Normal
# 2                         64                      Normal
# 3                         70                        Lots
# 4                         52                      Normal
# ...                      ...                         ...
# 1453                      53                      Normal
# 1454                      50                      Normal
# 1455                      32                      Little
# 1456                      32                      Little
# 1457                      32                      Little
#
#      chanceCreationPositioningClass  defencePressure defencePressureClass  \
# 0                         Organised               50               Medium
# 1                         Organised               47               Medium
# 2                         Organised               47               Medium
# 3                         Organised               60               Medium
# 4                         Organised               47               Medium
# ...                             ...              ...                  ...
# 1453                      Organised               46               Medium
# 1454                      Organised               44               Medium
# 1455                      Organised               44               Medium
# 1456                      Organised               44               Medium
# 1457                      Organised               44               Medium
#
#       defenceAggression defenceAggressionClass  defenceTeamWidth  \
# 0                    55                  Press                45
# 1                    44                  Press                54
# 2                    44                  Press                54
# 3                    70                 Double                70
# 4                    47                  Press                52
# ...                 ...                    ...               ...
# 1453                 48                  Press                53
# 1454                 55                  Press                53
# 1455                 58                  Press                37
# 1456                 58                  Press                37
# 1457                 58                  Press                37
#
#      defenceTeamWidthClass defenceDefenderLineClass
# 0                   Normal                    Cover
# 1                   Normal                    Cover
# 2                   Normal                    Cover
# 3                     Wide                    Cover
# 4                   Normal                    Cover
# ...                    ...                      ...
# 1453                Normal                    Cover
# 1454                Normal                    Cover
# 1455                Normal                    Cover
# 1456                Normal                    Cover
# 1457                Normal                    Cover
#
# [1458 rows x 27 columns]

# %%
df_match
# Out:
#           id  country_id     season  stage                 date  match_api_id  \
# 0          1           1  2008/2009      1  2008-08-17 00:00:00        492473
# 1          2           1  2008/2009      1  2008-08-16 00:00:00        492474
# 2          3           1  2008/2009      1  2008-08-16 00:00:00        492475
# 3          4           1  2008/2009      1  2008-08-17 00:00:00        492476
# 4          5           1  2008/2009      1  2008-08-16 00:00:00        492477
# ...      ...         ...        ...    ...                  ...           ...
# 25974  25975       24558  2015/2016      9  2015-09-22 00:00:00       1992091
# 25975  25976       24558  2015/2016      9  2015-09-23 00:00:00       1992092
# 25976  25977       24558  2015/2016      9  2015-09-23 00:00:00       1992093
# 25977  25978       24558  2015/2016      9  2015-09-22 00:00:00       1992094
# 25978  25979       24558  2015/2016      9  2015-09-23 00:00:00       1992095
#
#        home_team_api_id  away_team_api_id  home_team_goal  away_team_goal  \
# 0                  9987              9993               1               1
# 1                 10000              9994               0               0
# 2                  9984              8635               0               3
# 3                  9991              9998               5               0
# 4                  7947              9985               1               3
# ...                 ...               ...             ...             ...
# 25974             10190             10191               1               0
# 25975              9824             10199               1               2
# 25976              9956             10179               2               0
# 25977              7896             10243               0               0
# 25978             10192              9931               4               3
#
#        ...  away_player_10  away_player_11  goal  shoton  shotoff  foulcommit  \
# 0      ...             NaN             NaN  None    None     None        None
# 1      ...             NaN             NaN  None    None     None        None
# 2      ...             NaN             NaN  None    None     None        None
# 3      ...             NaN             NaN  None    None     None        None
# 4      ...             NaN             NaN  None    None     None        None
# ...    ...             ...             ...   ...     ...      ...         ...
# 25974  ...        232110.0        289732.0  None    None     None        None
# 25975  ...         34082.0         95257.0  None    None     None        None
# 25976  ...        451335.0        275122.0  None    None     None        None
# 25977  ...         92252.0        194532.0  None    None     None        None
# 25978  ...         41726.0        527103.0  None    None     None        None
#
#        card  cross  corner  possession
# 0      None   None    None        None
# 1      None   None    None        None
# 2      None   None    None        None
# 3      None   None    None        None
# 4      None   None    None        None
# ...     ...    ...     ...         ...
# 25974  None   None    None        None
# 25975  None   None    None        None
# 25976  None   None    None        None
# 25977  None   None    None        None
# 25978  None   None    None        None
#
# [25979 rows x 40 columns]

# %%
df_match = df_match.merge(df_country[['id', 'league_name', 'country_name']], left_on='country_id', right_on='id', how='left')

# %%
df_match
# Out:
#         id_x  country_id     season  stage                 date  match_api_id  \
# 0          1           1  2008/2009      1  2008-08-17 00:00:00        492473
# 1          2           1  2008/2009      1  2008-08-16 00:00:00        492474
# 2          3           1  2008/2009      1  2008-08-16 00:00:00        492475
# 3          4           1  2008/2009      1  2008-08-17 00:00:00        492476
# 4          5           1  2008/2009      1  2008-08-16 00:00:00        492477
# ...      ...         ...        ...    ...                  ...           ...
# 25974  25975       24558  2015/2016      9  2015-09-22 00:00:00       1992091
# 25975  25976       24558  2015/2016      9  2015-09-23 00:00:00       1992092
# 25976  25977       24558  2015/2016      9  2015-09-23 00:00:00       1992093
# 25977  25978       24558  2015/2016      9  2015-09-22 00:00:00       1992094
# 25978  25979       24558  2015/2016      9  2015-09-23 00:00:00       1992095
#
#        home_team_api_id  away_team_api_id  home_team_goal  away_team_goal  \
# 0                  9987              9993               1               1
# 1                 10000              9994               0               0
# 2                  9984              8635               0               3
# 3                  9991              9998               5               0
# 4                  7947              9985               1               3
# ...                 ...               ...             ...             ...
# 25974             10190             10191               1               0
# 25975              9824             10199               1               2
# 25976              9956             10179               2               0
# 25977              7896             10243               0               0
# 25978             10192              9931               4               3
#
#        ...  shoton  shotoff  foulcommit  card  cross  corner  possession  \
# 0      ...    None     None        None  None   None    None        None
# 1      ...    None     None        None  None   None    None        None
# 2      ...    None     None        None  None   None    None        None
# 3      ...    None     None        None  None   None    None        None
# 4      ...    None     None        None  None   None    None        None
# ...    ...     ...      ...         ...   ...    ...     ...         ...
# 25974  ...    None     None        None  None   None    None        None
# 25975  ...    None     None        None  None   None    None        None
# 25976  ...    None     None        None  None   None    None        None
# 25977  ...    None     None        None  None   None    None        None
# 25978  ...    None     None        None  None   None    None        None
#
#         id_y               league_name  country_name
# 0          1    Belgium Jupiler League       Belgium
# 1          1    Belgium Jupiler League       Belgium
# 2          1    Belgium Jupiler League       Belgium
# 3          1    Belgium Jupiler League       Belgium
# 4          1    Belgium Jupiler League       Belgium
# ...      ...                       ...           ...
# 25974  24558  Switzerland Super League   Switzerland
# 25975  24558  Switzerland Super League   Switzerland
# 25976  24558  Switzerland Super League   Switzerland
# 25977  24558  Switzerland Super League   Switzerland
# 25978  24558  Switzerland Super League   Switzerland
#
# [25979 rows x 43 columns]

# %%
print(df_match.columns.to_list())
df_match.drop('id_y',axis=1,inplace =True)
print(df_match.columns.to_list())
df_match.columns=['id', 'country_id', 'season', 'stage', 'date', 'match_api_id', 'home_team_api_id', 'away_team_api_id', 'home_team_goal', 'away_team_goal', 'home_player_1', 'home_player_2', 'home_player_3', 'home_player_4', 'home_player_5', 'home_player_6', 'home_player_7', 'home_player_8', 'home_player_9', 'home_player_10', 'home_player_11', 'away_player_1', 'away_player_2', 'away_player_3', 'away_player_4', 'away_player_5', 'away_player_6', 'away_player_7', 'away_player_8', 'away_player_9', 'away_player_10', 'away_player_11', 'goal', 'shoton', 'shotoff', 'foulcommit', 'card', 'cross', 'corner', 'possession', 'league_name', 'country_name']

df_match
# Out:
# ['id_x', 'country_id', 'season', 'stage', 'date', 'match_api_id', 'home_team_api_id', 'away_team_api_id', 'home_team_goal', 'away_team_goal', 'home_player_1', 'home_player_2', 'home_player_3', 'home_player_4', 'home_player_5', 'home_player_6', 'home_player_7', 'home_player_8', 'home_player_9', 'home_player_10', 'home_player_11', 'away_player_1', 'away_player_2', 'away_player_3', 'away_player_4', 'away_player_5', 'away_player_6', 'away_player_7', 'away_player_8', 'away_player_9', 'away_player_10', 'away_player_11', 'goal', 'shoton', 'shotoff', 'foulcommit', 'card', 'cross', 'corner', 'possession', 'id_y', 'league_name', 'country_name']
# ['id_x', 'country_id', 'season', 'stage', 'date', 'match_api_id', 'home_team_api_id', 'away_team_api_id', 'home_team_goal', 'away_team_goal', 'home_player_1', 'home_player_2', 'home_player_3', 'home_player_4', 'home_player_5', 'home_player_6', 'home_player_7', 'home_player_8', 'home_player_9', 'home_player_10', 'home_player_11', 'away_player_1', 'away_player_2', 'away_player_3', 'away_player_4', 'away_player_5', 'away_player_6', 'away_player_7', 'away_player_8', 'away_player_9', 'away_player_10', 'away_player_11', 'goal', 'shoton', 'shotoff', 'foulcommit', 'card', 'cross', 'corner', 'possession', 'league_name', 'country_name']
#           id  country_id     season  stage                 date  match_api_id  \
# 0          1           1  2008/2009      1  2008-08-17 00:00:00        492473
# 1          2           1  2008/2009      1  2008-08-16 00:00:00        492474
# 2          3           1  2008/2009      1  2008-08-16 00:00:00        492475
# 3          4           1  2008/2009      1  2008-08-17 00:00:00        492476
# 4          5           1  2008/2009      1  2008-08-16 00:00:00        492477
# ...      ...         ...        ...    ...                  ...           ...
# 25974  25975       24558  2015/2016      9  2015-09-22 00:00:00       1992091
# 25975  25976       24558  2015/2016      9  2015-09-23 00:00:00       1992092
# 25976  25977       24558  2015/2016      9  2015-09-23 00:00:00       1992093
# 25977  25978       24558  2015/2016      9  2015-09-22 00:00:00       1992094
# 25978  25979       24558  2015/2016      9  2015-09-23 00:00:00       1992095
#
#        home_team_api_id  away_team_api_id  home_team_goal  away_team_goal  \
# 0                  9987              9993               1               1
# 1                 10000              9994               0               0
# 2                  9984              8635               0               3
# 3                  9991              9998               5               0
# 4                  7947              9985               1               3
# ...                 ...               ...             ...             ...
# 25974             10190             10191               1               0
# 25975              9824             10199               1               2
# 25976              9956             10179               2               0
# 25977              7896             10243               0               0
# 25978             10192              9931               4               3
#
#        ...  goal  shoton  shotoff  foulcommit  card  cross  corner  \
# 0      ...  None    None     None        None  None   None    None
# 1      ...  None    None     None        None  None   None    None
# 2      ...  None    None     None        None  None   None    None
# 3      ...  None    None     None        None  None   None    None
# 4      ...  None    None     None        None  None   None    None
# ...    ...   ...     ...      ...         ...   ...    ...     ...
# 25974  ...  None    None     None        None  None   None    None
# 25975  ...  None    None     None        None  None   None    None
# 25976  ...  None    None     None        None  None   None    None
# 25977  ...  None    None     None        None  None   None    None
# 25978  ...  None    None     None        None  None   None    None
#
#        possession               league_name  country_name
# 0            None    Belgium Jupiler League       Belgium
# 1            None    Belgium Jupiler League       Belgium
# 2            None    Belgium Jupiler League       Belgium
# 3            None    Belgium Jupiler League       Belgium
# 4            None    Belgium Jupiler League       Belgium
# ...           ...                       ...           ...
# 25974        None  Switzerland Super League   Switzerland
# 25975        None  Switzerland Super League   Switzerland
# 25976        None  Switzerland Super League   Switzerland
# 25977        None  Switzerland Super League   Switzerland
# 25978        None  Switzerland Super League   Switzerland
#
# [25979 rows x 42 columns]

# %% [markdown]
# ## now merge the team

# %%
new_df_team= df_team.drop_duplicates(subset='team_id')

# %%
df_match = df_match.merge(new_df_team[['team_id', 'team_long_name']], left_on='home_team_api_id', right_on= 'team_id', how='left')
df_match.rename(columns={'team_long_name': 'home_team'}, inplace=True)
df_match.drop('team_id',axis=1,inplace=True)
df_match = df_match.merge(new_df_team[['team_id', 'team_long_name']], left_on='away_team_api_id', right_on= 'team_id', how='left')
df_match.rename(columns={'team_long_name': 'away_team'}, inplace=True)
df_match.drop('team_id',axis=1,inplace=True)
df_match
# Out:
#           id  country_id     season  stage                 date  match_api_id  \
# 0          1           1  2008/2009      1  2008-08-17 00:00:00        492473
# 1          2           1  2008/2009      1  2008-08-16 00:00:00        492474
# 2          3           1  2008/2009      1  2008-08-16 00:00:00        492475
# 3          4           1  2008/2009      1  2008-08-17 00:00:00        492476
# 4          5           1  2008/2009      1  2008-08-16 00:00:00        492477
# ...      ...         ...        ...    ...                  ...           ...
# 25974  25975       24558  2015/2016      9  2015-09-22 00:00:00       1992091
# 25975  25976       24558  2015/2016      9  2015-09-23 00:00:00       1992092
# 25976  25977       24558  2015/2016      9  2015-09-23 00:00:00       1992093
# 25977  25978       24558  2015/2016      9  2015-09-22 00:00:00       1992094
# 25978  25979       24558  2015/2016      9  2015-09-23 00:00:00       1992095
#
#        home_team_api_id  away_team_api_id  home_team_goal  away_team_goal  \
# 0                  9987              9993               1               1
# 1                 10000              9994               0               0
# 2                  9984              8635               0               3
# 3                  9991              9998               5               0
# 4                  7947              9985               1               3
# ...                 ...               ...             ...             ...
# 25974             10190             10191               1               0
# 25975              9824             10199               1               2
# 25976              9956             10179               2               0
# 25977              7896             10243               0               0
# 25978             10192              9931               4               3
#
#        ...  shotoff  foulcommit  card  cross  corner  possession  \
# 0      ...     None        None  None   None    None        None
# 1      ...     None        None  None   None    None        None
# 2      ...     None        None  None   None    None        None
# 3      ...     None        None  None   None    None        None
# 4      ...     None        None  None   None    None        None
# ...    ...      ...         ...   ...    ...     ...         ...
# 25974  ...     None        None  None   None    None        None
# 25975  ...     None        None  None   None    None        None
# 25976  ...     None        None  None   None    None        None
# 25977  ...     None        None  None   None    None        None
# 25978  ...     None        None  None   None    None        None
#
#                     league_name  country_name                home_team  \
# 0        Belgium Jupiler League       Belgium                 KRC Genk
# 1        Belgium Jupiler League       Belgium         SV Zulte-Waregem
# 2        Belgium Jupiler League       Belgium        KSV Cercle Brugge
# 3        Belgium Jupiler League       Belgium                 KAA Gent
# 4        Belgium Jupiler League       Belgium                      NaN
# ...                         ...           ...                      ...
# 25974  Switzerland Super League   Switzerland            FC St. Gallen
# 25975  Switzerland Super League   Switzerland                 FC Vaduz
# 25976  Switzerland Super League   Switzerland  Grasshopper Club Zürich
# 25977  Switzerland Super League   Switzerland                      NaN
# 25978  Switzerland Super League   Switzerland           BSC Young Boys
#
#                away_team
# 0           Beerschot AC
# 1       Sporting Lokeren
# 2         RSC Anderlecht
# 3              RAEC Mons
# 4      Standard de Liège
# ...                  ...
# 25974            FC Thun
# 25975          FC Luzern
# 25976            FC Sion
# 25977          FC Zürich
# 25978           FC Basel
#
# [25979 rows x 44 columns]

# %% [markdown]
# # now i have table player and table match and table team

# %%
display(df_team.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458 entries, 0 to 1457
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id_team                         1458 non-null   int64
#  1   team_long_name                  1458 non-null   object
#  2   team_short_name                 1458 non-null   object
#  3   id_team_attribute               1458 non-null   int64
#  4   team_id                         1458 non-null   int64
#  5   date                            1458 non-null   object
#  6   buildUpPlaySpeed                1458 non-null   int64
#  7   buildUpPlaySpeedClass           1458 non-null   object
#  8   buildUpPlayDribbling            489 non-null    float64
#  9   buildUpPlayDribblingClass       1458 non-null   object
#  10  buildUpPlayPassing              1458 non-null   int64
#  11  buildUpPlayPassingClass         1458 non-null   object
#  12  buildUpPlayPositioningClass     1458 non-null   object
#  13  chanceCreationPassing           1458 non-null   int64
#  14  chanceCreationPassingClass      1458 non-null   object
#  15  chanceCreationCrossing          1458 non-null   int64
#  16  chanceCreationCrossingClass     1458 non-null   object
#  17  chanceCreationShooting          1458 non-null   int64
#  18  chanceCreationShootingClass     1458 non-null   object
#  19  chanceCreationPositioningClass  1458 non-null   object
#  20  defencePressure                 1458 non-null   int64
#  21  defencePressureClass            1458 non-null   object
#  22  defenceAggression               1458 non-null   int64
#  23  defenceAggressionClass          1458 non-null   object
#  24  defenceTeamWidth                1458 non-null   int64
#  25  defenceTeamWidthClass           1458 non-null   object
#  26  defenceDefenderLineClass        1458 non-null   object
# dtypes: float64(1), int64(11), object(15)
# memory usage: 307.7+ KB
# None

# %%
print(df_match.columns.to_list())
# Out:
# ['id', 'country_id', 'season', 'stage', 'date', 'match_api_id', 'home_team_api_id', 'away_team_api_id', 'home_team_goal', 'away_team_goal', 'home_player_1', 'home_player_2', 'home_player_3', 'home_player_4', 'home_player_5', 'home_player_6', 'home_player_7', 'home_player_8', 'home_player_9', 'home_player_10', 'home_player_11', 'away_player_1', 'away_player_2', 'away_player_3', 'away_player_4', 'away_player_5', 'away_player_6', 'away_player_7', 'away_player_8', 'away_player_9', 'away_player_10', 'away_player_11', 'goal', 'shoton', 'shotoff', 'foulcommit', 'card', 'cross', 'corner', 'possession', 'league_name', 'country_name', 'home_team', 'away_team']

# %%
df_player['date'] = pd.to_datetime(df_player['date'])

df_player['season'] = df_player['date'].apply(lambda x: f"{x.year}/{x.year + 1}" if x.month >= 8 else f"{x.year - 1}/{x.year}")
df_player
# Out:
#         id_player         player_name             birthday  height  weight  \
# 0               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 1               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 2               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 3               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 4               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# ...           ...                 ...                  ...     ...     ...
# 183973      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
# 183974      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
# 183975      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
# 183976      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
# 183977      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
#
#         id_attribute  player_id       date  overall_rating  potential  ...  \
# 0                  1     505942 2016-02-18            67.0       71.0  ...
# 1                  2     505942 2015-11-19            67.0       71.0  ...
# 2                  3     505942 2015-09-21            62.0       66.0  ...
# 3                  4     505942 2015-03-20            61.0       65.0  ...
# 4                  5     505942 2007-02-22            61.0       65.0  ...
# ...              ...        ...        ...             ...        ...  ...
# 183973        183974      39902 2009-08-30            83.0       85.0  ...
# 183974        183975      39902 2009-02-22            78.0       80.0  ...
# 183975        183976      39902 2008-08-30            77.0       80.0  ...
# 183976        183977      39902 2007-08-30            78.0       81.0  ...
# 183977        183978      39902 2007-02-22            80.0       81.0  ...
#
#        penalties marking standing_tackle  sliding_tackle  gk_diving  \
# 0           48.0    65.0            69.0            69.0        6.0
# 1           48.0    65.0            69.0            69.0        6.0
# 2           48.0    65.0            66.0            69.0        6.0
# 3           47.0    62.0            63.0            66.0        5.0
# 4           47.0    62.0            63.0            66.0        5.0
# ...          ...     ...             ...             ...        ...
# 183973      83.0    22.0            31.0            30.0        9.0
# 183974      70.0    32.0            31.0            30.0        9.0
# 183975      70.0    32.0            31.0            30.0        9.0
# 183976      53.0    28.0            32.0            30.0        9.0
# 183977      53.0    38.0            32.0            30.0        9.0
#
#         gk_handling  gk_kicking  gk_positioning  gk_reflexes     season
# 0              11.0        10.0             8.0          8.0  2015/2016
# 1              11.0        10.0             8.0          8.0  2015/2016
# 2              11.0        10.0             8.0          8.0  2015/2016
# 3              10.0         9.0             7.0          7.0  2014/2015
# 4              10.0         9.0             7.0          7.0  2006/2007
# ...             ...         ...             ...          ...        ...
# 183973         20.0        84.0            20.0         20.0  2009/2010
# 183974         20.0        73.0            20.0         20.0  2008/2009
# 183975         20.0        73.0            20.0         20.0  2008/2009
# 183976         20.0        73.0            20.0         20.0  2007/2008
# 183977          9.0        78.0             7.0         15.0  2006/2007
#
# [183978 rows x 47 columns]

# %%
# i am thinking of dealing with null value  in the general analyses 
# and in the  model i am gonna romeve outliers and do standarization

# %% [markdown]
# # __________________________________________________

# %% [markdown]
# # working on the dataframe of the  general analyse

# %%
df_player.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183978 entries, 0 to 183977
# Data columns (total 47 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id_player            183978 non-null  int64
#  1   player_name          183978 non-null  object
#  2   birthday             183978 non-null  object
#  3   height               183978 non-null  float64
#  4   weight               183978 non-null  int64
#  5   id_attribute         183978 non-null  int64
#  6   player_id            183978 non-null  int64
#  7   date                 183978 non-null  datetime64[ns]
#  8   overall_rating       183142 non-null  float64
#  9   potential            183142 non-null  float64
#  10  preferred_foot       183142 non-null  object
#  11  attacking_work_rate  180748 non-null  object
#  12  defensive_work_rate  183142 non-null  object
#  13  crossing             183142 non-null  float64
#  14  finishing            183142 non-null  float64
#  15  heading_accuracy     183142 non-null  float64
#  16  short_passing        183142 non-null  float64
#  17  volleys              181265 non-null  float64
#  18  dribbling            183142 non-null  float64
#  19  curve                181265 non-null  float64
#  20  free_kick_accuracy   183142 non-null  float64
#  21  long_passing         183142 non-null  float64
#  22  ball_control         183142 non-null  float64
#  23  acceleration         183142 non-null  float64
#  24  sprint_speed         183142 non-null  float64
#  25  agility              181265 non-null  float64
#  26  reactions            183142 non-null  float64
#  27  balance              181265 non-null  float64
#  28  shot_power           183142 non-null  float64
#  29  jumping              181265 non-null  float64
#  30  stamina              183142 non-null  float64
#  31  strength             183142 non-null  float64
#  32  long_shots           183142 non-null  float64
#  33  aggression           183142 non-null  float64
#  34  interceptions        183142 non-null  float64
#  35  positioning          183142 non-null  float64
#  36  vision               181265 non-null  float64
#  37  penalties            183142 non-null  float64
#  38  marking              183142 non-null  float64
#  39  standing_tackle      183142 non-null  float64
#  40  sliding_tackle       181265 non-null  float64
#  41  gk_diving            183142 non-null  float64
#  42  gk_handling          183142 non-null  float64
#  43  gk_kicking           183142 non-null  float64
#  44  gk_positioning       183142 non-null  float64
#  45  gk_reflexes          183142 non-null  float64
#  46  season               183978 non-null  object
# dtypes: datetime64[ns](1), float64(36), int64(4), object(6)
# memory usage: 66.0+ MB

# %%
import matplotlib.pyplot as plt

# Plot the distribution of 'overall_rating'
plt.figure(figsize=(10,6))
plt.hist(df_player['overall_rating'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Overall Rating')
plt.xlabel('Overall Rating')
plt.ylabel('Frequency')
plt.show()

print(df_player['overall_rating'].skew())
# Out:
# -0.19936732712920865

# %%
plt.figure(figsize=(10,6))
plt.hist(df_player['potential'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of potential')
plt.xlabel('potential')
plt.ylabel('Frequency')
plt.show()


print(df_player['potential'].skew())
# Out:
# -0.03883902376554089

# %% [markdown]
# # since the ditrubition is symetrique i am gonna use mean

# %%
df_player['potential'].fillna(df_player['potential'].mean(), inplace = True)
df_player['overall_rating'].fillna(df_player['overall_rating'].mean(), inplace = True)
# Out:
# /tmp/ipykernel_18965/1370173321.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_player['potential'].fillna(df_player['potential'].mean(), inplace = True)
# /tmp/ipykernel_18965/1370173321.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_player['overall_rating'].fillna(df_player['overall_rating'].mean(), inplace = True)

# %%
# here i filled the missing value in tableau player 

df_player.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183978 entries, 0 to 183977
# Data columns (total 47 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id_player            183978 non-null  int64
#  1   player_name          183978 non-null  object
#  2   birthday             183978 non-null  object
#  3   height               183978 non-null  float64
#  4   weight               183978 non-null  int64
#  5   id_attribute         183978 non-null  int64
#  6   player_id            183978 non-null  int64
#  7   date                 183978 non-null  datetime64[ns]
#  8   overall_rating       183978 non-null  float64
#  9   potential            183978 non-null  float64
#  10  preferred_foot       183142 non-null  object
#  11  attacking_work_rate  180748 non-null  object
#  12  defensive_work_rate  183142 non-null  object
#  13  crossing             183142 non-null  float64
#  14  finishing            183142 non-null  float64
#  15  heading_accuracy     183142 non-null  float64
#  16  short_passing        183142 non-null  float64
#  17  volleys              181265 non-null  float64
#  18  dribbling            183142 non-null  float64
#  19  curve                181265 non-null  float64
#  20  free_kick_accuracy   183142 non-null  float64
#  21  long_passing         183142 non-null  float64
#  22  ball_control         183142 non-null  float64
#  23  acceleration         183142 non-null  float64
#  24  sprint_speed         183142 non-null  float64
#  25  agility              181265 non-null  float64
#  26  reactions            183142 non-null  float64
#  27  balance              181265 non-null  float64
#  28  shot_power           183142 non-null  float64
#  29  jumping              181265 non-null  float64
#  30  stamina              183142 non-null  float64
#  31  strength             183142 non-null  float64
#  32  long_shots           183142 non-null  float64
#  33  aggression           183142 non-null  float64
#  34  interceptions        183142 non-null  float64
#  35  positioning          183142 non-null  float64
#  36  vision               181265 non-null  float64
#  37  penalties            183142 non-null  float64
#  38  marking              183142 non-null  float64
#  39  standing_tackle      183142 non-null  float64
#  40  sliding_tackle       181265 non-null  float64
#  41  gk_diving            183142 non-null  float64
#  42  gk_handling          183142 non-null  float64
#  43  gk_kicking           183142 non-null  float64
#  44  gk_positioning       183142 non-null  float64
#  45  gk_reflexes          183142 non-null  float64
#  46  season               183978 non-null  object
# dtypes: datetime64[ns](1), float64(36), int64(4), object(6)
# memory usage: 66.0+ MB

# %%
print(df_match.columns.to_list())
# Out:
# ['id', 'country_id', 'season', 'stage', 'date', 'match_api_id', 'home_team_api_id', 'away_team_api_id', 'home_team_goal', 'away_team_goal', 'home_player_1', 'home_player_2', 'home_player_3', 'home_player_4', 'home_player_5', 'home_player_6', 'home_player_7', 'home_player_8', 'home_player_9', 'home_player_10', 'home_player_11', 'away_player_1', 'away_player_2', 'away_player_3', 'away_player_4', 'away_player_5', 'away_player_6', 'away_player_7', 'away_player_8', 'away_player_9', 'away_player_10', 'away_player_11', 'goal', 'shoton', 'shotoff', 'foulcommit', 'card', 'cross', 'corner', 'possession', 'league_name', 'country_name', 'home_team', 'away_team']

# %%
# cheking match
df_match
df_match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25979 entries, 0 to 25978
# Data columns (total 44 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                25979 non-null  int64
#  1   country_id        25979 non-null  int64
#  2   season            25979 non-null  object
#  3   stage             25979 non-null  int64
#  4   date              25979 non-null  object
#  5   match_api_id      25979 non-null  int64
#  6   home_team_api_id  25979 non-null  int64
#  7   away_team_api_id  25979 non-null  int64
#  8   home_team_goal    25979 non-null  int64
#  9   away_team_goal    25979 non-null  int64
#  10  home_player_1     24755 non-null  float64
#  11  home_player_2     24664 non-null  float64
#  12  home_player_3     24698 non-null  float64
#  13  home_player_4     24656 non-null  float64
#  14  home_player_5     24663 non-null  float64
#  15  home_player_6     24654 non-null  float64
#  16  home_player_7     24752 non-null  float64
#  17  home_player_8     24670 non-null  float64
#  18  home_player_9     24706 non-null  float64
#  19  home_player_10    24543 non-null  float64
#  20  home_player_11    24424 non-null  float64
#  21  away_player_1     24745 non-null  float64
#  22  away_player_2     24701 non-null  float64
#  23  away_player_3     24686 non-null  float64
#  24  away_player_4     24658 non-null  float64
#  25  away_player_5     24644 non-null  float64
#  26  away_player_6     24666 non-null  float64
#  27  away_player_7     24744 non-null  float64
#  28  away_player_8     24638 non-null  float64
#  29  away_player_9     24651 non-null  float64
#  30  away_player_10    24538 non-null  float64
#  31  away_player_11    24425 non-null  float64
#  32  goal              14217 non-null  object
#  33  shoton            14217 non-null  object
#  34  shotoff           14217 non-null  object
#  35  foulcommit        14217 non-null  object
#  36  card              14217 non-null  object
#  37  cross             14217 non-null  object
#  38  corner            14217 non-null  object
#  39  possession        14217 non-null  object
#  40  league_name       25979 non-null  object
#  41  country_name      25979 non-null  object
#  42  home_team         25801 non-null  object
#  43  away_team         25801 non-null  object
# dtypes: float64(22), int64(8), object(14)
# memory usage: 8.7+ MB

# %%
# after cheking table  match is ready

# %%
df_team.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458 entries, 0 to 1457
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id_team                         1458 non-null   int64
#  1   team_long_name                  1458 non-null   object
#  2   team_short_name                 1458 non-null   object
#  3   id_team_attribute               1458 non-null   int64
#  4   team_id                         1458 non-null   int64
#  5   date                            1458 non-null   object
#  6   buildUpPlaySpeed                1458 non-null   int64
#  7   buildUpPlaySpeedClass           1458 non-null   object
#  8   buildUpPlayDribbling            489 non-null    float64
#  9   buildUpPlayDribblingClass       1458 non-null   object
#  10  buildUpPlayPassing              1458 non-null   int64
#  11  buildUpPlayPassingClass         1458 non-null   object
#  12  buildUpPlayPositioningClass     1458 non-null   object
#  13  chanceCreationPassing           1458 non-null   int64
#  14  chanceCreationPassingClass      1458 non-null   object
#  15  chanceCreationCrossing          1458 non-null   int64
#  16  chanceCreationCrossingClass     1458 non-null   object
#  17  chanceCreationShooting          1458 non-null   int64
#  18  chanceCreationShootingClass     1458 non-null   object
#  19  chanceCreationPositioningClass  1458 non-null   object
#  20  defencePressure                 1458 non-null   int64
#  21  defencePressureClass            1458 non-null   object
#  22  defenceAggression               1458 non-null   int64
#  23  defenceAggressionClass          1458 non-null   object
#  24  defenceTeamWidth                1458 non-null   int64
#  25  defenceTeamWidthClass           1458 non-null   object
#  26  defenceDefenderLineClass        1458 non-null   object
# dtypes: float64(1), int64(11), object(15)
# memory usage: 307.7+ KB

# %%
# after cheking table  team is ready

# %% [markdown]
#  # ___________________________________________

# %% [markdown]
# # this section for the models where i am gonna do more transformation

# %% [markdown]
# ### starting with player

# %%
df_player
# Out:
#         id_player         player_name             birthday  height  weight  \
# 0               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 1               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 2               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 3               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# 4               1  Aaron Appindangoye  1992-02-29 00:00:00  182.88     187
# ...           ...                 ...                  ...     ...     ...
# 183973      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
# 183974      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
# 183975      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
# 183976      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
# 183977      11075  Zvjezdan Misimovic  1982-06-05 00:00:00  180.34     176
#
#         id_attribute  player_id       date  overall_rating  potential  ...  \
# 0                  1     505942 2016-02-18            67.0       71.0  ...
# 1                  2     505942 2015-11-19            67.0       71.0  ...
# 2                  3     505942 2015-09-21            62.0       66.0  ...
# 3                  4     505942 2015-03-20            61.0       65.0  ...
# 4                  5     505942 2007-02-22            61.0       65.0  ...
# ...              ...        ...        ...             ...        ...  ...
# 183973        183974      39902 2009-08-30            83.0       85.0  ...
# 183974        183975      39902 2009-02-22            78.0       80.0  ...
# 183975        183976      39902 2008-08-30            77.0       80.0  ...
# 183976        183977      39902 2007-08-30            78.0       81.0  ...
# 183977        183978      39902 2007-02-22            80.0       81.0  ...
#
#        penalties marking standing_tackle  sliding_tackle  gk_diving  \
# 0           48.0    65.0            69.0            69.0        6.0
# 1           48.0    65.0            69.0            69.0        6.0
# 2           48.0    65.0            66.0            69.0        6.0
# 3           47.0    62.0            63.0            66.0        5.0
# 4           47.0    62.0            63.0            66.0        5.0
# ...          ...     ...             ...             ...        ...
# 183973      83.0    22.0            31.0            30.0        9.0
# 183974      70.0    32.0            31.0            30.0        9.0
# 183975      70.0    32.0            31.0            30.0        9.0
# 183976      53.0    28.0            32.0            30.0        9.0
# 183977      53.0    38.0            32.0            30.0        9.0
#
#         gk_handling  gk_kicking  gk_positioning  gk_reflexes     season
# 0              11.0        10.0             8.0          8.0  2015/2016
# 1              11.0        10.0             8.0          8.0  2015/2016
# 2              11.0        10.0             8.0          8.0  2015/2016
# 3              10.0         9.0             7.0          7.0  2014/2015
# 4              10.0         9.0             7.0          7.0  2006/2007
# ...             ...         ...             ...          ...        ...
# 183973         20.0        84.0            20.0         20.0  2009/2010
# 183974         20.0        73.0            20.0         20.0  2008/2009
# 183975         20.0        73.0            20.0         20.0  2008/2009
# 183976         20.0        73.0            20.0         20.0  2007/2008
# 183977          9.0        78.0             7.0         15.0  2006/2007
#
# [183978 rows x 47 columns]

# %%
df_player[config.cluster_player].info()
config.cluster_player
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183978 entries, 0 to 183977
# Data columns (total 16 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   overall_rating       183978 non-null  float64
#  1   potential            183978 non-null  float64
#  2   height               183978 non-null  float64
#  3   weight               183978 non-null  int64
#  4   preferred_foot       183142 non-null  object
#  5   attacking_work_rate  180748 non-null  object
#  6   positioning          183142 non-null  float64
#  7   penalties            183142 non-null  float64
#  8   finishing            183142 non-null  float64
#  9   crossing             183142 non-null  float64
#  10  short_passing        183142 non-null  float64
#  11  long_passing         183142 non-null  float64
#  12  shot_power           183142 non-null  float64
#  13  aggression           183142 non-null  float64
#  14  free_kick_accuracy   183142 non-null  float64
#  15  defensive_work_rate  183142 non-null  object
# dtypes: float64(12), int64(1), object(3)
# memory usage: 22.5+ MB
# ['overall_rating',
#  'potential',
#  'height',
#  'weight',
#  'preferred_foot',
#  'attacking_work_rate',
#  'positioning',
#  'penalties',
#  'finishing',
#  'crossing',
#  'short_passing',
#  'long_passing',
#  'shot_power',
#  'aggression',
#  'free_kick_accuracy',
#  'defensive_work_rate']

# %%
# i tried every  column
plt.figure(figsize=(10,6))
plt.hist(df_player['height'], bins=20, color='skyblue', edgecolor='black')
plt.title('height')
plt.xlabel('height')
plt.ylabel('Frequency')
plt.show()


print(df_player['height'].skew())
# Out:
# -0.025200547223997782

# %%
df_player['preferred_foot'] = df_player['preferred_foot'].fillna(df_player['preferred_foot'].mode()[0])
df_player['attacking_work_rate'] = df_player['attacking_work_rate'].fillna(df_player['attacking_work_rate'].mode()[0])
df_player['defensive_work_rate'] = df_player['defensive_work_rate'].fillna(df_player['defensive_work_rate'].mode()[0])


df_player['positioning'] = df_player['positioning'].fillna(df_player['positioning'].median())
df_player['penalties'] = df_player['penalties'].fillna(df_player['penalties'].median())
df_player['finishing'] = df_player['finishing'].fillna(df_player['finishing'].median())
df_player['crossing'] = df_player['crossing'].fillna(df_player['crossing'].median())
df_player['short_passing'] = df_player['short_passing'].fillna(df_player['short_passing'].median())
df_player['long_passing'] = df_player['long_passing'].fillna(df_player['long_passing'].median())
df_player['shot_power'] = df_player['shot_power'].fillna(df_player['shot_power'].median())
df_player['aggression'] = df_player['aggression'].fillna(df_player['aggression'].median())
df_player['free_kick_accuracy'] = df_player['free_kick_accuracy'].fillna(df_player['free_kick_accuracy'].median())

# %%
df_player.head()
# Out:
#    id_player         player_name             birthday    height    weight  \
# 0          1  Aaron Appindangoye  1992-02-29 00:00:00  0.156553  1.207761
# 1          1  Aaron Appindangoye  1992-02-29 00:00:00  0.156553  1.207761
# 2          1  Aaron Appindangoye  1992-02-29 00:00:00  0.156553  1.207761
# 3          1  Aaron Appindangoye  1992-02-29 00:00:00  0.156553  1.207761
# 4          1  Aaron Appindangoye  1992-02-29 00:00:00  0.156553  1.207761
#
#    id_attribute  player_id       date  overall_rating  potential  ...  \
# 0             1     505942 2016-02-18       -0.227757  -0.374070  ...
# 1             2     505942 2015-11-19       -0.227757  -0.374070  ...
# 2             3     505942 2015-09-21       -0.939490  -1.134265  ...
# 3             4     505942 2015-03-20       -1.081837  -1.286304  ...
# 4             5     505942 2007-02-22       -1.081837  -1.286304  ...
#
#    penalties  marking  standing_tackle  sliding_tackle  gk_diving  \
# 0  -0.452114     65.0             69.0            69.0        6.0
# 1  -0.452114     65.0             69.0            69.0        6.0
# 2  -0.452114     65.0             66.0            69.0        6.0
# 3  -0.516582     62.0             63.0            66.0        5.0
# 4  -0.516582     62.0             63.0            66.0        5.0
#
#    gk_handling  gk_kicking  gk_positioning  gk_reflexes     season
# 0         11.0        10.0             8.0          8.0  2015/2016
# 1         11.0        10.0             8.0          8.0  2015/2016
# 2         11.0        10.0             8.0          8.0  2015/2016
# 3         10.0         9.0             7.0          7.0  2014/2015
# 4         10.0         9.0             7.0          7.0  2006/2007
#
# [5 rows x 47 columns]

# %%
df_player[config.cluster_player].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183978 entries, 0 to 183977
# Data columns (total 16 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   overall_rating       183978 non-null  float64
#  1   potential            183978 non-null  float64
#  2   height               183978 non-null  float64
#  3   weight               183978 non-null  int64
#  4   preferred_foot       183978 non-null  object
#  5   attacking_work_rate  183978 non-null  object
#  6   positioning          183978 non-null  float64
#  7   penalties            183978 non-null  float64
#  8   finishing            183978 non-null  float64
#  9   crossing             183978 non-null  float64
#  10  short_passing        183978 non-null  float64
#  11  long_passing         183978 non-null  float64
#  12  shot_power           183978 non-null  float64
#  13  aggression           183978 non-null  float64
#  14  free_kick_accuracy   183978 non-null  float64
#  15  defensive_work_rate  183978 non-null  object
# dtypes: float64(12), int64(1), object(3)
# memory usage: 22.5+ MB

# %%
df_player[['positioning', 'penalties', 'finishing', 'crossing', 'short_passing', 'long_passing', 'shot_power', 'aggression', 'free_kick_accuracy']].skew()
# Out:
# positioning          -0.737734
# penalties            -0.472576
# finishing            -0.290102
# crossing             -0.742606
# short_passing        -1.203907
# long_passing         -0.658628
# shot_power           -0.952861
# aggression           -0.632932
# free_kick_accuracy   -0.213555
# dtype: float64

# %%
df_player[['overall_rating', 'potential', 'height', 'weight']].skew()
# Out:
# overall_rating   -0.199822
# potential        -0.038928
# height           -0.025201
# weight            0.193348
# dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler,StandardScaler

scaler = StandardScaler()
df_player[['overall_rating',
 'potential',
 'height',
 'weight',
 'positioning',
 'penalties',
 'finishing',
 'crossing',
 'short_passing',
 'long_passing',
 'shot_power',
 'aggression',
 'free_kick_accuracy']]=scaler.fit_transform(df_player[['overall_rating',
 'potential',
 'height',
 'weight',
 'positioning',
 'penalties',
 'finishing',
 'crossing',
 'short_passing',
 'long_passing',
 'shot_power',
 'aggression',
 'free_kick_accuracy']])

# %%
#  i completed the standarization 
df_player[config.cluster_player]
# Out:
#         overall_rating  potential    height    weight preferred_foot  \
# 0            -0.227757  -0.374070  0.156553  1.207761          right
# 1            -0.227757  -0.374070  0.156553  1.207761          right
# 2            -0.939490  -1.134265  0.156553  1.207761          right
# 3            -1.081837  -1.286304  0.156553  1.207761          right
# 4            -1.081837  -1.286304  0.156553  1.207761          right
# ...                ...        ...       ...       ...            ...
# 183973        2.049789   1.754477 -0.240644  0.478747          right
# 183974        1.338056   0.994282 -0.240644  0.478747          right
# 183975        1.195710   0.994282 -0.240644  0.478747          right
# 183976        1.338056   1.146321 -0.240644  0.478747          right
# 183977        1.622749   1.146321 -0.240644  0.478747          right
#
#        attacking_work_rate  positioning  penalties  finishing  crossing  \
# 0                   medium    -0.586994  -0.452114  -0.312430 -0.354822
# 1                   medium    -0.586994  -0.452114  -0.312430 -0.354822
# 2                   medium    -0.586994  -0.452114  -0.312430 -0.354822
# 3                   medium    -0.641317  -0.516582  -0.365071 -0.412945
# 4                   medium    -0.641317  -0.516582  -0.365071 -0.412945
# ...                    ...          ...        ...        ...       ...
# 183973              medium     1.640243   1.804248   1.424734  1.679485
# 183974              medium     0.879723   0.966171   1.372093  1.098254
# 183975              medium     0.879723   0.966171   1.108886  1.098254
# 183976              medium     0.662432  -0.129777   0.740397  1.098254
# 183977              medium     0.662432  -0.129777   0.950962  1.098254
#
#         short_passing  long_passing  shot_power  aggression  \
# 0           -0.101770      0.481912   -0.423789    0.625263
# 1           -0.101770      0.481912   -0.423789    0.625263
# 2           -0.101770      0.481912   -0.423789    0.126950
# 3           -0.172378      0.412285   -0.485901    0.064661
# 4           -0.172378      0.412285   -0.485901    0.064661
# ...               ...           ...         ...         ...
# 183973       1.875240      1.874450    0.880573   -0.309073
# 183974       1.522203      1.108554    0.818460    0.002372
# 183975       1.522203      1.108554    0.818460    0.376107
# 183976       1.663418      1.108554    0.632123    0.126950
# 183977       1.804633      1.456688    0.632123    0.126950
#
#         free_kick_accuracy defensive_work_rate
# 0                -0.583646              medium
# 1                -0.583646              medium
# 2                -0.583646              medium
# 3                -0.639854              medium
# 4                -0.639854              medium
# ...                    ...                 ...
# 183973            1.608450                 low
# 183974            1.383620                 low
# 183975            1.383620                 low
# 183976            1.327412                 low
# 183977            0.203260                 low
#
# [183978 rows x 16 columns]

# %%
# now i ll be starting encoding

print(df_player['preferred_foot'].unique())
print(df_player['attacking_work_rate'].unique())
print(df_player['defensive_work_rate'].unique())
# Out:
# ['right' 'left']
# ['medium' 'high' 'low' 'None' 'le' 'norm' 'stoc' 'y']
# ['medium' 'high' 'low' '_0' '5' 'ean' 'o' '1' 'ormal' '7' '2' '8' '4'
#  'tocky' '0' '3' '6' '9' 'es']

# %%
df_player['preferred_foot'].value_counts()
# Out:
# preferred_foot
# right    139245
# left      44733
# Name: count, dtype: int64

# %%
df_player['defensive_work_rate']=df_player['defensive_work_rate'].apply(lambda x : 'medium' if x not in ['medium','high','low'] else x)
df_player['defensive_work_rate'].value_counts()
# Out:
# defensive_work_rate
# medium    138505
# high       27041
# low        18432
# Name: count, dtype: int64

# %%
df_player['attacking_work_rate']=df_player['attacking_work_rate'].apply(lambda x : 'medium' if x not in ['medium','high','low'] else x)
df_player['attacking_work_rate'].value_counts()
# Out:
# attacking_work_rate
# medium    132586
# high       42823
# low         8569
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

label_encoder =LabelEncoder()
df_player['preferred_foot']=label_encoder.fit_transform(df_player['preferred_foot'])
df_player['attacking_work_rate']=label_encoder.fit_transform(df_player['attacking_work_rate'])
df_player['defensive_work_rate']=label_encoder.fit_transform(df_player['defensive_work_rate'])

# %%
df_player[config.cluster_player]
# Out:
#         overall_rating  potential    height    weight  preferred_foot  \
# 0            -0.227757  -0.374070  0.156553  1.207761               1
# 1            -0.227757  -0.374070  0.156553  1.207761               1
# 2            -0.939490  -1.134265  0.156553  1.207761               1
# 3            -1.081837  -1.286304  0.156553  1.207761               1
# 4            -1.081837  -1.286304  0.156553  1.207761               1
# ...                ...        ...       ...       ...             ...
# 183973        2.049789   1.754477 -0.240644  0.478747               1
# 183974        1.338056   0.994282 -0.240644  0.478747               1
# 183975        1.195710   0.994282 -0.240644  0.478747               1
# 183976        1.338056   1.146321 -0.240644  0.478747               1
# 183977        1.622749   1.146321 -0.240644  0.478747               1
#
#         attacking_work_rate  positioning  penalties  finishing  crossing  \
# 0                         2    -0.586994  -0.452114  -0.312430 -0.354822
# 1                         2    -0.586994  -0.452114  -0.312430 -0.354822
# 2                         2    -0.586994  -0.452114  -0.312430 -0.354822
# 3                         2    -0.641317  -0.516582  -0.365071 -0.412945
# 4                         2    -0.641317  -0.516582  -0.365071 -0.412945
# ...                     ...          ...        ...        ...       ...
# 183973                    2     1.640243   1.804248   1.424734  1.679485
# 183974                    2     0.879723   0.966171   1.372093  1.098254
# 183975                    2     0.879723   0.966171   1.108886  1.098254
# 183976                    2     0.662432  -0.129777   0.740397  1.098254
# 183977                    2     0.662432  -0.129777   0.950962  1.098254
#
#         short_passing  long_passing  shot_power  aggression  \
# 0           -0.101770      0.481912   -0.423789    0.625263
# 1           -0.101770      0.481912   -0.423789    0.625263
# 2           -0.101770      0.481912   -0.423789    0.126950
# 3           -0.172378      0.412285   -0.485901    0.064661
# 4           -0.172378      0.412285   -0.485901    0.064661
# ...               ...           ...         ...         ...
# 183973       1.875240      1.874450    0.880573   -0.309073
# 183974       1.522203      1.108554    0.818460    0.002372
# 183975       1.522203      1.108554    0.818460    0.376107
# 183976       1.663418      1.108554    0.632123    0.126950
# 183977       1.804633      1.456688    0.632123    0.126950
#
#         free_kick_accuracy  defensive_work_rate
# 0                -0.583646                    2
# 1                -0.583646                    2
# 2                -0.583646                    2
# 3                -0.639854                    2
# 4                -0.639854                    2
# ...                    ...                  ...
# 183973            1.608450                    1
# 183974            1.383620                    1
# 183975            1.383620                    1
# 183976            1.327412                    1
# 183977            0.203260                    1
#
# [183978 rows x 16 columns]

# %%
df_player
# Out:
#         id_player         player_name             birthday    height  \
# 0               1  Aaron Appindangoye  1992-02-29 00:00:00  0.156553
# 1               1  Aaron Appindangoye  1992-02-29 00:00:00  0.156553
# 2               1  Aaron Appindangoye  1992-02-29 00:00:00  0.156553
# 3               1  Aaron Appindangoye  1992-02-29 00:00:00  0.156553
# 4               1  Aaron Appindangoye  1992-02-29 00:00:00  0.156553
# ...           ...                 ...                  ...       ...
# 183973      11075  Zvjezdan Misimovic  1982-06-05 00:00:00 -0.240644
# 183974      11075  Zvjezdan Misimovic  1982-06-05 00:00:00 -0.240644
# 183975      11075  Zvjezdan Misimovic  1982-06-05 00:00:00 -0.240644
# 183976      11075  Zvjezdan Misimovic  1982-06-05 00:00:00 -0.240644
# 183977      11075  Zvjezdan Misimovic  1982-06-05 00:00:00 -0.240644
#
#           weight  id_attribute  player_id       date  overall_rating  \
# 0       1.207761             1     505942 2016-02-18       -0.227757
# 1       1.207761             2     505942 2015-11-19       -0.227757
# 2       1.207761             3     505942 2015-09-21       -0.939490
# 3       1.207761             4     505942 2015-03-20       -1.081837
# 4       1.207761             5     505942 2007-02-22       -1.081837
# ...          ...           ...        ...        ...             ...
# 183973  0.478747        183974      39902 2009-08-30        2.049789
# 183974  0.478747        183975      39902 2009-02-22        1.338056
# 183975  0.478747        183976      39902 2008-08-30        1.195710
# 183976  0.478747        183977      39902 2007-08-30        1.338056
# 183977  0.478747        183978      39902 2007-02-22        1.622749
#
#         potential  ...  penalties  marking  standing_tackle  sliding_tackle  \
# 0       -0.374070  ...  -0.452114     65.0             69.0            69.0
# 1       -0.374070  ...  -0.452114     65.0             69.0            69.0
# 2       -1.134265  ...  -0.452114     65.0             66.0            69.0
# 3       -1.286304  ...  -0.516582     62.0             63.0            66.0
# 4       -1.286304  ...  -0.516582     62.0             63.0            66.0
# ...           ...  ...        ...      ...              ...             ...
# 183973   1.754477  ...   1.804248     22.0             31.0            30.0
# 183974   0.994282  ...   0.966171     32.0             31.0            30.0
# 183975   0.994282  ...   0.966171     32.0             31.0            30.0
# 183976   1.146321  ...  -0.129777     28.0             32.0            30.0
# 183977   1.146321  ...  -0.129777     38.0             32.0            30.0
#
#         gk_diving  gk_handling  gk_kicking  gk_positioning  gk_reflexes  \
# 0             6.0         11.0        10.0             8.0          8.0
# 1             6.0         11.0        10.0             8.0          8.0
# 2             6.0         11.0        10.0             8.0          8.0
# 3             5.0         10.0         9.0             7.0          7.0
# 4             5.0         10.0         9.0             7.0          7.0
# ...           ...          ...         ...             ...          ...
# 183973        9.0         20.0        84.0            20.0         20.0
# 183974        9.0         20.0        73.0            20.0         20.0
# 183975        9.0         20.0        73.0            20.0         20.0
# 183976        9.0         20.0        73.0            20.0         20.0
# 183977        9.0          9.0        78.0             7.0         15.0
#
#            season
# 0       2015/2016
# 1       2015/2016
# 2       2015/2016
# 3       2014/2015
# 4       2006/2007
# ...           ...
# 183973  2009/2010
# 183974  2008/2009
# 183975  2008/2009
# 183976  2007/2008
# 183977  2006/2007
#
# [183978 rows x 47 columns]

# %% [markdown]
# #### i fineshed  the  player table and now is ready for the model

# %% [markdown]
# #### ______________ now i will start the  team table ____________________

# %%
display(df_team[config.cluster_team].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1458 entries, 0 to 1457
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   buildUpPlaySpeed          1458 non-null   int64
#  1   buildUpPlaySpeedClass     1458 non-null   object
#  2   buildUpPlayPassing        1458 non-null   int64
#  3   chanceCreationPassing     1458 non-null   int64
#  4   chanceCreationCrossing    1458 non-null   int64
#  5   chanceCreationShooting    1458 non-null   int64
#  6   defencePressure           1458 non-null   int64
#  7   defenceAggression         1458 non-null   int64
#  8   defenceDefenderLineClass  1458 non-null   object
# dtypes: int64(7), object(2)
# memory usage: 102.6+ KB
# None

# %%
team_int = ['buildUpPlaySpeed', 'buildUpPlayPassing', 'chanceCreationPassing', 'chanceCreationCrossing', 'chanceCreationShooting', 'defencePressure', 'defenceAggression']
team_obj = ['buildUpPlaySpeedClass', 'buildUpPlayDribblingClass', 'buildUpPlayPassingClass', 'chanceCreationPassingClass', 'chanceCreationCrossingClass', 'chanceCreationShootingClass', 'defencePressureClass', 'defenceAggressionClass',  'defenceDefenderLineClass']

# %%
df_team.head()
# Out:
#    id_team team_long_name team_short_name  id_team_attribute  team_id  \
# 0    49119       FC Aarau             AAR                  1     9930
# 1    49119       FC Aarau             AAR                  2     9930
# 2    49119       FC Aarau             AAR                  3     9930
# 3    39393       Aberdeen             ABE                  4     8485
# 4    39393       Aberdeen             ABE                  5     8485
#
#                   date  buildUpPlaySpeed buildUpPlaySpeedClass  \
# 0  2010-02-22 00:00:00                60              Balanced
# 1  2014-09-19 00:00:00                52              Balanced
# 2  2015-09-10 00:00:00                47              Balanced
# 3  2010-02-22 00:00:00                70                  Fast
# 4  2011-02-22 00:00:00                47              Balanced
#
#    buildUpPlayDribbling buildUpPlayDribblingClass  ...  \
# 0                   NaN                    Little  ...
# 1                  48.0                    Normal  ...
# 2                  41.0                    Normal  ...
# 3                   NaN                    Little  ...
# 4                   NaN                    Little  ...
#
#    chanceCreationShooting chanceCreationShootingClass  \
# 0                      55                      Normal
# 1                      64                      Normal
# 2                      64                      Normal
# 3                      70                        Lots
# 4                      52                      Normal
#
#   chanceCreationPositioningClass  defencePressure defencePressureClass  \
# 0                      Organised               50               Medium
# 1                      Organised               47               Medium
# 2                      Organised               47               Medium
# 3                      Organised               60               Medium
# 4                      Organised               47               Medium
#
#    defenceAggression defenceAggressionClass  defenceTeamWidth  \
# 0                 55                  Press                45
# 1                 44                  Press                54
# 2                 44                  Press                54
# 3                 70                 Double                70
# 4                 47                  Press                52
#
#   defenceTeamWidthClass defenceDefenderLineClass
# 0                Normal                    Cover
# 1                Normal                    Cover
# 2                Normal                    Cover
# 3                  Wide                    Cover
# 4                Normal                    Cover
#
# [5 rows x 27 columns]

# %%
df_team[team_int].skew()
# Out:
# buildUpPlaySpeed         -0.267856
# buildUpPlayPassing        0.119354
# chanceCreationPassing    -0.034483
# chanceCreationCrossing   -0.204666
# chanceCreationShooting   -0.174795
# defencePressure           0.342438
# defenceAggression         0.218809
# dtype: float64

# %%
df_team[team_int]=scaler.fit_transform(df_team[team_int])

# %%
df_team[team_int]
# Out:
#       buildUpPlaySpeed  buildUpPlayPassing  chanceCreationPassing  \
# 0             0.653074            0.138593               0.756447
# 1            -0.040052            0.689437               0.177142
# 2            -0.473256            0.505822               0.177142
# 3             1.519482            1.974741               1.721956
# 4            -0.473256            0.322208               0.080591
# ...                ...                 ...                    ...
# 1453         -0.040052            0.322208              -0.015959
# 1454          0.133230            0.230400              -0.498713
# 1455          0.133230            0.230400              -0.498713
# 1456          0.133230            0.230400              -0.498713
# 1457          0.133230            0.230400              -0.498713
#
#       chanceCreationCrossing  chanceCreationShooting  defencePressure  \
# 0                   1.016709                0.099851         0.389570
# 1                   0.836252                0.971604         0.096135
# 2                   0.836252                0.971604         0.096135
# 3                   1.467850                1.552773         1.367688
# 4                  -0.517173               -0.190733         0.096135
# ...                      ...                     ...              ...
# 1453               -0.517173               -0.093872        -0.001677
# 1454               -0.156260               -0.384456        -0.197301
# 1455               -0.156260               -2.127963        -0.197301
# 1456               -0.156260               -2.127963        -0.197301
# 1457               -0.156260               -2.127963        -0.197301
#
#       defenceAggression
# 0              0.590566
# 1             -0.539414
# 2             -0.539414
# 3              2.131447
# 4             -0.231238
# ...                 ...
# 1453          -0.128512
# 1454           0.590566
# 1455           0.898742
# 1456           0.898742
# 1457           0.898742
#
# [1458 rows x 7 columns]

# %%
# here i done the standarization  and now i ll do the encoding

# %%
for ele in team_obj:
    print(df_team[ele].unique())
# Out:
# ['Balanced' 'Fast' 'Slow']
# ['Little' 'Normal' 'Lots']
# ['Mixed' 'Long' 'Short']
# ['Normal' 'Risky' 'Safe']
# ['Normal' 'Lots' 'Little']
# ['Normal' 'Lots' 'Little']
# ['Medium' 'Deep' 'High']
# ['Press' 'Double' 'Contain']
# ['Cover' 'Offside Trap']

# %%
for ele in team_obj:
    df_team[ele]=label_encoder.fit_transform(df_team[ele])

# %%
for ele in team_obj:
    print(df_team[ele].unique())
# Out:
# [0 1 2]
# [0 2 1]
# [1 0 2]
# [0 1 2]
# [2 1 0]
# [2 1 0]
# [2 0 1]
# [2 1 0]
# [0 1]

# %%
df_team[config.cluster_team]
# Out:
#       buildUpPlaySpeed  buildUpPlaySpeedClass  buildUpPlayPassing  \
# 0             0.653074                      0            0.138593
# 1            -0.040052                      0            0.689437
# 2            -0.473256                      0            0.505822
# 3             1.519482                      1            1.974741
# 4            -0.473256                      0            0.322208
# ...                ...                    ...                 ...
# 1453         -0.040052                      0            0.322208
# 1454          0.133230                      0            0.230400
# 1455          0.133230                      0            0.230400
# 1456          0.133230                      0            0.230400
# 1457          0.133230                      0            0.230400
#
#       chanceCreationPassing  chanceCreationCrossing  chanceCreationShooting  \
# 0                  0.756447                1.016709                0.099851
# 1                  0.177142                0.836252                0.971604
# 2                  0.177142                0.836252                0.971604
# 3                  1.721956                1.467850                1.552773
# 4                  0.080591               -0.517173               -0.190733
# ...                     ...                     ...                     ...
# 1453              -0.015959               -0.517173               -0.093872
# 1454              -0.498713               -0.156260               -0.384456
# 1455              -0.498713               -0.156260               -2.127963
# 1456              -0.498713               -0.156260               -2.127963
# 1457              -0.498713               -0.156260               -2.127963
#
#       defencePressure  defenceAggression  defenceDefenderLineClass
# 0            0.389570           0.590566                         0
# 1            0.096135          -0.539414                         0
# 2            0.096135          -0.539414                         0
# 3            1.367688           2.131447                         0
# 4            0.096135          -0.231238                         0
# ...               ...                ...                       ...
# 1453        -0.001677          -0.128512                         0
# 1454        -0.197301           0.590566                         0
# 1455        -0.197301           0.898742                         0
# 1456        -0.197301           0.898742                         0
# 1457        -0.197301           0.898742                         0
#
# [1458 rows x 9 columns]

# %% [markdown]
# ### here i finished the data for the models (both model)

# %% [markdown]
# # now all i need to do is to do the analyses and create the models
